# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv sin indice 

Portland = pd.read_csv('Datos_Limpios_portland.csv')

# %%
#Verificamos informacion del dataframe
Portland.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3858 entries, 0 to 3857
# Data columns (total 49 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0.1                                  3858 non-null   int64
#  1   host_since                                    3858 non-null   object
#  2   host_response_time                            3858 non-null   object
#  3   host_response_rate                            3858 non-null   object
#  4   host_acceptance_rate                          3858 non-null   object
#  5   host_verifications                            3858 non-null   object
#  6   neighbourhood_cleansed                        3858 non-null   object
#  7   property_type                                 3858 non-null   object
#  8   room_type                                     3858 non-null   object
#  9   bathrooms_text                                3858 non-null   object
#  10  amenities                                     3858 non-null   object
#  11  price                                         3858 non-null   object
#  12  has_availability                              3858 non-null   object
#  13  first_review                                  3858 non-null   object
#  14  last_review                                   3858 non-null   object
#  15  instant_bookable                              3858 non-null   object
#  16  Unnamed: 0                                    3858 non-null   int64
#  17  host_id                                       3858 non-null   int64
#  18  host_listings_count                           3858 non-null   float64
#  19  host_total_listings_count                     3858 non-null   float64
#  20  latitude                                      3858 non-null   float64
#  21  longitude                                     3858 non-null   float64
#  22  accommodates                                  3858 non-null   float64
#  23  bathrooms                                     3858 non-null   float64
#  24  bedrooms                                      3858 non-null   float64
#  25  beds                                          3858 non-null   float64
#  26  minimum_nights                                3858 non-null   float64
#  27  maximum_nights                                3858 non-null   int64
#  28  minimum_nights_avg_ntm                        3858 non-null   float64
#  29  maximum_nights_avg_ntm                        3858 non-null   float64
#  30  availability_30                               3858 non-null   int64
#  31  availability_60                               3858 non-null   int64
#  32  availability_90                               3858 non-null   int64
#  33  availability_365                              3858 non-null   int64
#  34  number_of_reviews                             3858 non-null   float64
#  35  number_of_reviews_ltm                         3858 non-null   float64
#  36  number_of_reviews_l30d                        3858 non-null   float64
#  37  review_scores_rating                          3858 non-null   float64
#  38  review_scores_accuracy                        3858 non-null   float64
#  39  review_scores_cleanliness                     3858 non-null   float64
#  40  review_scores_checkin                         3858 non-null   float64
#  41  review_scores_communication                   3858 non-null   float64
#  42  review_scores_location                        3858 non-null   float64
#  43  review_scores_value                           3858 non-null   float64
#  44  calculated_host_listings_count                3858 non-null   float64
#  45  calculated_host_listings_count_entire_homes   3858 non-null   float64
#  46  calculated_host_listings_count_private_rooms  3858 non-null   float64
#  47  calculated_host_listings_count_shared_rooms   3858 non-null   float64
#  48  reviews_per_month                             3858 non-null   float64
# dtypes: float64(26), int64(8), object(15)
# memory usage: 1.4+ MB

# %%
#Mostramos los primeros 5 registros 
Portland.head()
# Out:
#    Unnamed: 0.1  host_since  host_response_time host_response_rate  \
# 0             0  18/04/2011  a few days or more                 0%
# 1             1  12/05/2011      within an hour               100%
# 2             2  01/07/2011      within an hour               100%
# 3             3  14/04/2010  within a few hours               100%
# 4             4  16/07/2011      within an hour               100%
#
#   host_acceptance_rate  host_verifications neighbourhood_cleansed  \
# 0                   6%  ['email', 'phone']                 Hadern
# 1                  99%  ['email', 'phone']           Berg am Laim
# 2                  78%  ['email', 'phone']     Pasing-Obermenzing
# 3                 100%  ['email', 'phone']      Sendling-Westpark
# 4                  67%  ['email', 'phone']            Maxvorstadt
#
#                  property_type        room_type bathrooms_text  ...  \
# 0           Entire rental unit  Entire home/apt         1 bath  ...
# 1           Entire rental unit  Entire home/apt         1 bath  ...
# 2           Entire rental unit  Entire home/apt         1 bath  ...
# 3         Private room in home     Private room  1 shared bath  ...
# 4  Private room in rental unit     Private room  1 shared bath  ...
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                      4.81                  4.90                        4.93
# 1                      4.95                  4.97                        5.00
# 2                      4.27                  4.78                        4.80
# 3                      4.99                  4.99                        4.98
# 4                      4.91                  4.89                        4.88
#
#   review_scores_location review_scores_value calculated_host_listings_count  \
# 0                   4.78                4.73                            2.0
# 1                   4.66                4.61                            3.0
# 2                   4.59                4.44                            1.0
# 3                   4.77                4.91                            1.0
# 4                   4.82                4.79                            1.0
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          2.0
# 1                                          3.0
# 2                                          1.0
# 3                                          0.0
# 4                                          0.0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                           0.0
# 1                                           0.0
# 2                                           0.0
# 3                                           1.0
# 4                                           1.0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                          0.0               0.80
# 1                                          0.0               0.46
# 2                                          0.0               0.26
# 3                                          0.0               3.58
# 4                                          0.0               0.74
#
# [5 rows x 49 columns]

# %%
#Eliminamos columnas innecesarias 
Portland = Portland.drop(['Unnamed: 0'], axis=1)

# %%
#Verificamos las columnas 
Portland.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3858 entries, 0 to 3857
# Data columns (total 48 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0.1                                  3858 non-null   int64
#  1   host_since                                    3858 non-null   object
#  2   host_response_time                            3858 non-null   object
#  3   host_response_rate                            3858 non-null   object
#  4   host_acceptance_rate                          3858 non-null   object
#  5   host_verifications                            3858 non-null   object
#  6   neighbourhood_cleansed                        3858 non-null   object
#  7   property_type                                 3858 non-null   object
#  8   room_type                                     3858 non-null   object
#  9   bathrooms_text                                3858 non-null   object
#  10  amenities                                     3858 non-null   object
#  11  price                                         3858 non-null   object
#  12  has_availability                              3858 non-null   object
#  13  first_review                                  3858 non-null   object
#  14  last_review                                   3858 non-null   object
#  15  instant_bookable                              3858 non-null   object
#  16  host_id                                       3858 non-null   int64
#  17  host_listings_count                           3858 non-null   float64
#  18  host_total_listings_count                     3858 non-null   float64
#  19  latitude                                      3858 non-null   float64
#  20  longitude                                     3858 non-null   float64
#  21  accommodates                                  3858 non-null   float64
#  22  bathrooms                                     3858 non-null   float64
#  23  bedrooms                                      3858 non-null   float64
#  24  beds                                          3858 non-null   float64
#  25  minimum_nights                                3858 non-null   float64
#  26  maximum_nights                                3858 non-null   int64
#  27  minimum_nights_avg_ntm                        3858 non-null   float64
#  28  maximum_nights_avg_ntm                        3858 non-null   float64
#  29  availability_30                               3858 non-null   int64
#  30  availability_60                               3858 non-null   int64
#  31  availability_90                               3858 non-null   int64
#  32  availability_365                              3858 non-null   int64
#  33  number_of_reviews                             3858 non-null   float64
#  34  number_of_reviews_ltm                         3858 non-null   float64
#  35  number_of_reviews_l30d                        3858 non-null   float64
#  36  review_scores_rating                          3858 non-null   float64
#  37  review_scores_accuracy                        3858 non-null   float64
#  38  review_scores_cleanliness                     3858 non-null   float64
#  39  review_scores_checkin                         3858 non-null   float64
#  40  review_scores_communication                   3858 non-null   float64
#  41  review_scores_location                        3858 non-null   float64
#  42  review_scores_value                           3858 non-null   float64
#  43  calculated_host_listings_count                3858 non-null   float64
#  44  calculated_host_listings_count_entire_homes   3858 non-null   float64
#  45  calculated_host_listings_count_private_rooms  3858 non-null   float64
#  46  calculated_host_listings_count_shared_rooms   3858 non-null   float64
#  47  reviews_per_month                             3858 non-null   float64
# dtypes: float64(26), int64(7), object(15)
# memory usage: 1.4+ MB

# %%
#Obtenemos un análisis univariado de las variables categoricas
freq_tbl(Portland)
# Out:
#       host_since  frequency  percentage  cumulative_perc
# 0     25/11/2020         72    0.018663         0.018663
# 1     17/12/2015         26    0.006739         0.025402
# 2     30/08/2011         21    0.005443         0.030845
# 3     03/05/2023         17    0.004406         0.035251
# 4     02/08/2013         15    0.003888         0.039139
# ...          ...        ...         ...              ...
# 2088  17/08/2019          1    0.000259         0.998963
# 2089  16/06/2022          1    0.000259         0.999222
# 2090  28/01/2017          1    0.000259         0.999482
# 2091  11/08/2015          1    0.000259         0.999741
# 2092  01/05/2016          1    0.000259         1.000000
#
# [2093 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       1938    0.502333         0.502333
# 1  within a few hours        967    0.250648         0.752981
# 2        within a day        693    0.179627         0.932608
# 3  a few days or more        260    0.067392         1.000000
#
# ----------------------------------------------------------------
#
#    host_response_rate  frequency  percentage  cumulative_perc
# 0                100%       2631    0.681960         0.681960
# 1                 90%        160    0.041472         0.723432
# 2                  0%        126    0.032659         0.756091
# 3                 80%         98    0.025402         0.781493
# 4                 92%         94    0.024365         0.805858
# ..                ...        ...         ...              ...
# 58                46%          1    0.000259         0.998963
# 59                18%          1    0.000259         0.999222
# 60                29%          1    0.000259         0.999482
# 61                52%          1    0.000259         0.999741
# 62                68%          1    0.000259         1.000000
#
# [63 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%        918    0.237947         0.237947
# 1                    0%        146    0.037843         0.275791
# 2                   99%        134    0.034733         0.310524
# 3                   98%        119    0.030845         0.341369
# 4                   97%        111    0.028771         0.370140
# ..                  ...        ...         ...              ...
# 95                   5%          4    0.001037         0.997149
# 96                   7%          3    0.000778         0.997926
# 97                   3%          3    0.000778         0.998704
# 98                   9%          3    0.000778         0.999482
# 99                  34%          2    0.000518         1.000000
#
# [100 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']       3023    0.783567         0.783567
# 1  ['email', 'phone', 'work_email']        433    0.112234         0.895801
# 2                         ['phone']        395    0.102385         0.998186
# 3           ['phone', 'work_email']          7    0.001814         1.000000
#
# ----------------------------------------------------------------
#
#                                neighbourhood_cleansed  frequency  percentage  \
# 0                        Ludwigsvorstadt-Isarvorstadt        496    0.128564
# 1                                         Maxvorstadt        312    0.080871
# 2                                       Au-Haidhausen        231    0.059876
# 3                                      Schwabing-West        209    0.054173
# 4                               Neuhausen-Nymphenburg        206    0.053396
# 5                                  Ramersdorf-Perlach        174    0.045101
# 6                                  Schwabing-Freimann        171    0.044323
# 7   Thalkirchen-Obersendling-Forstenried-Fürstenri...        164    0.042509
# 8                                   Sendling-Westpark        164    0.042509
# 9                                       Tudering-Riem        157    0.040695
# 10                                        Bogenhausen        157    0.040695
# 11                              Milbertshofen-Am Hart        145    0.037584
# 12                                        Obergiesing        144    0.037325
# 13                                     Altstadt-Lehel        132    0.034215
# 14                                           Sendling        121    0.031363
# 15                         Aubing-Lochhausen-Langwied        118    0.030586
# 16                            Untergiesing-Harlaching        115    0.029808
# 17                                   Schwanthalerhöhe        115    0.029808
# 18                                               Laim        111    0.028771
# 19                                 Pasing-Obermenzing        104    0.026957
# 20                                       Berg am Laim         89    0.023069
# 21                             Feldmoching-Hasenbergl         74    0.019181
# 22                                            Moosach         70    0.018144
# 23                                             Hadern         40    0.010368
# 24                                Allach-Untermenzing         39    0.010109
#
#     cumulative_perc
# 0          0.128564
# 1          0.209435
# 2          0.269311
# 3          0.323484
# 4          0.376879
# 5          0.421980
# 6          0.466304
# 7          0.508813
# 8          0.551322
# 9          0.592017
# 10         0.632711
# 11         0.670295
# 12         0.707621
# 13         0.741835
# 14         0.773199
# 15         0.803784
# 16         0.833593
# 17         0.863401
# 18         0.892172
# 19         0.919129
# 20         0.942198
# 21         0.961379
# 22         0.979523
# 23         0.989891
# 24         1.000000
#
# ----------------------------------------------------------------
#
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       1983    0.513997         0.513997
# 1          Private room in rental unit        835    0.216433         0.730430
# 2                         Entire condo        207    0.053655         0.784085
# 3                 Private room in home        167    0.043287         0.827372
# 4            Entire serviced apartment        166    0.043027         0.870399
# 5                Private room in condo        107    0.027735         0.898134
# 6                        Room in hotel         66    0.017107         0.915241
# 7                          Entire home         52    0.013478         0.928720
# 8            Private room in townhouse         50    0.012960         0.941680
# 9                          Entire loft         50    0.012960         0.954640
# 10                  Room in aparthotel         22    0.005702         0.960342
# 11              Room in boutique hotel         20    0.005184         0.965526
# 12                    Entire townhouse         13    0.003370         0.968896
# 13  Private room in serviced apartment         11    0.002851         0.971747
# 14   Private room in bed and breakfast          9    0.002333         0.974080
# 15          Private room in guesthouse          9    0.002333         0.976413
# 16          Shared room in rental unit          9    0.002333         0.978745
# 17                  Entire guest suite          7    0.001814         0.980560
# 18                        Entire villa          6    0.001555         0.982115
# 19                Private room in loft          6    0.001555         0.983670
# 20     Private room in casa particular          6    0.001555         0.985226
# 21                        Private room          5    0.001296         0.986522
# 22                   Entire guesthouse          5    0.001296         0.987818
# 23          Room in serviced apartment          4    0.001037         0.988854
# 24                  Shipping container          4    0.001037         0.989891
# 25                           Camper/RV          4    0.001037         0.990928
# 26       Private room in vacation home          3    0.000778         0.991706
# 27                           Tiny home          3    0.000778         0.992483
# 28                        Entire place          3    0.000778         0.993261
# 29                Entire vacation home          3    0.000778         0.994038
# 30                     Entire bungalow          3    0.000778         0.994816
# 31               Shared room in hostel          2    0.000518         0.995334
# 32         Private room in guest suite          2    0.000518         0.995853
# 33    Shared room in bed and breakfast          2    0.000518         0.996371
# 34               Private room in villa          2    0.000518         0.996890
# 35                 Shared room in home          2    0.000518         0.997408
# 36                        Entire cabin          1    0.000259         0.997667
# 37             Shared room in ice dome          1    0.000259         0.997926
# 38           Private room in farm stay          1    0.000259         0.998186
# 39                      Shepherd’s hut          1    0.000259         0.998445
# 40                         Shared room          1    0.000259         0.998704
# 41            Private room in bungalow          1    0.000259         0.998963
# 42                             Pension          1    0.000259         0.999222
# 43                Shared room in condo          1    0.000259         0.999482
# 44                                 Hut          1    0.000259         0.999741
# 45                                Tent          1    0.000259         1.000000
#
# ----------------------------------------------------------------
#
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       2522    0.653707         0.653707
# 1     Private room       1303    0.337740         0.991446
# 2      Shared room         18    0.004666         0.996112
# 3       Hotel room         15    0.003888         1.000000
#
# ----------------------------------------------------------------
#
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath       2274    0.589425         0.589425
# 1       1 shared bath        577    0.149559         0.738984
# 2      1 private bath        271    0.070244         0.809228
# 3           1.5 baths        256    0.066356         0.875583
# 4             2 baths        177    0.045879         0.921462
# 5    1.5 shared baths        135    0.034992         0.956454
# 6           2.5 baths         39    0.010109         0.966563
# 7      2 shared baths         28    0.007258         0.973821
# 8           Half-bath         20    0.005184         0.979005
# 9    Shared half-bath         20    0.005184         0.984189
# 10            3 baths         16    0.004147         0.988336
# 11            0 baths         11    0.002851         0.991187
# 12     0 shared baths          6    0.001555         0.992742
# 13     3 shared baths          6    0.001555         0.994298
# 14   2.5 shared baths          5    0.001296         0.995594
# 15          3.5 baths          5    0.001296         0.996890
# 16  Private half-bath          5    0.001296         0.998186
# 17            4 baths          4    0.001037         0.999222
# 18            5 baths          1    0.000259         0.999482
# 19     4 shared baths          1    0.000259         0.999741
# 20            8 baths          1    0.000259         1.000000
#
# ----------------------------------------------------------------
#
#                                               amenities  frequency  \
# 0     ["Smoke alarm", "Fire extinguisher", "Dedicate...         12
# 1     ["Dryer", "Dishes and silverware", "Dedicated ...         11
# 2     ["Heating", "Coffee maker", "Self check-in", "...          9
# 3     ["Dryer", "Dishes and silverware", "Dedicated ...          7
# 4     ["Luggage dropoff allowed", "Heating", "Hot wa...          6
# ...                                                 ...        ...
# 3688  ["Hangers", "Hot water", "Washer", "Heating", ...          1
# 3689  ["Outdoor furniture", "Heating", "Hot water ke...          1
# 3690  ["Heating", "Hot water kettle", "Coffee maker"...          1
# 3691  ["Heating", "Single level home", "Lockbox", "S...          1
# 3692  ["Smoke alarm", "Air conditioning", "Lockbox",...          1
#
#       percentage  cumulative_perc
# 0       0.003110         0.003110
# 1       0.002851         0.005962
# 2       0.002333         0.008294
# 3       0.001814         0.010109
# 4       0.001555         0.011664
# ...          ...              ...
# 3688    0.000259         0.998963
# 3689    0.000259         0.999222
# 3690    0.000259         0.999482
# 3691    0.000259         0.999741
# 3692    0.000259         1.000000
#
# [3693 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#          price  frequency  percentage  cumulative_perc
# 0      $150.00        105    0.027216         0.027216
# 1      $120.00         90    0.023328         0.050544
# 2      $200.00         73    0.018922         0.069466
# 3      $100.00         65    0.016848         0.086314
# 4      $250.00         63    0.016330         0.102644
# ..         ...        ...         ...              ...
# 635  $1,566.00          1    0.000259         0.998963
# 636    $327.00          1    0.000259         0.999222
# 637    $829.00          1    0.000259         0.999482
# 638    $850.00          1    0.000259         0.999741
# 639    $488.00          1    0.000259         1.000000
#
# [640 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   has_availability  frequency  percentage  cumulative_perc
# 0                t       3858         1.0              1.0
#
# ----------------------------------------------------------------
#
#      first_review  frequency  percentage  cumulative_perc
# 0      22/09/2024         66    0.017107         0.017107
# 1      24/09/2023         60    0.015552         0.032659
# 2      17/09/2023         45    0.011664         0.044323
# 3      21/06/2024         42    0.010886         0.055210
# 4      23/09/2024         37    0.009590         0.064800
# ...           ...        ...         ...              ...
# 1524   04/10/2018          1    0.000259         0.998963
# 1525   24/10/2018          1    0.000259         0.999222
# 1526   16/07/2021          1    0.000259         0.999482
# 1527   04/01/2019          1    0.000259         0.999741
# 1528   29/01/2020          1    0.000259         1.000000
#
# [1529 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#     last_review  frequency  percentage  cumulative_perc
# 0    01/09/2024        297    0.076983         0.076983
# 1    22/09/2024        269    0.069725         0.146708
# 2    23/09/2024        213    0.055210         0.201918
# 3    25/08/2024        142    0.036807         0.238725
# 4    18/08/2024        105    0.027216         0.265941
# ..          ...        ...         ...              ...
# 507  18/09/2020          1    0.000259         0.998963
# 508  21/09/2022          1    0.000259         0.999222
# 509  14/05/2023          1    0.000259         0.999482
# 510  20/11/2023          1    0.000259         0.999741
# 511  05/06/2024          1    0.000259         1.000000
#
# [512 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       3111    0.806376         0.806376
# 1                t        747    0.193624         1.000000
#
# ----------------------------------------------------------------

# %%
#Obtenemos un analisis univariado de una variable categorica en especifico
tabla1 = freq_tbl(Portland['room_type'])
tabla1
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       2522    0.653707         0.653707
# 1     Private room       1303    0.337740         0.991446
# 2      Shared room         18    0.004666         0.996112
# 3       Hotel room         15    0.003888         1.000000

# %%
#Realizamos grafico de dispersion del dataframe filtrado
tabla1.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
tabla2 = freq_tbl(Portland['instant_bookable'])
tabla2
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       3111    0.806376         0.806376
# 1                t        747    0.193624         1.000000

# %%
tabla3 = tabla2.drop(['percentage', 'cumulative_perc'], axis=1)
tabla3
# Out:
#   instant_bookable  frequency
# 0                f       3111
# 1                t        747

# %%
filtro = tabla2[(tabla2["frequency"] > 1000)]
filtro
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       3111    0.806376         0.806376

# %%
#Ajusto el indice de mi DataFrame
filtro_index = filtro.set_index('instant_bookable')
filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# instant_bookable
# f                      3111    0.806376         0.806376

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('instant_bookable')
plt.xlabel('Tipo de instant_bookable')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla4 = freq_tbl(Portland['host_since'])
tabla4
# Out:
#       host_since  frequency  percentage  cumulative_perc
# 0     25/11/2020         72    0.018663         0.018663
# 1     17/12/2015         26    0.006739         0.025402
# 2     30/08/2011         21    0.005443         0.030845
# 3     03/05/2023         17    0.004406         0.035251
# 4     02/08/2013         15    0.003888         0.039139
# ...          ...        ...         ...              ...
# 2088  17/08/2019          1    0.000259         0.998963
# 2089  16/06/2022          1    0.000259         0.999222
# 2090  28/01/2017          1    0.000259         0.999482
# 2091  11/08/2015          1    0.000259         0.999741
# 2092  01/05/2016          1    0.000259         1.000000
#
# [2093 rows x 4 columns]

# %%
#Realizamos grafico de dispersion del dataframe filtrado
tabla4.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
tabla5 = freq_tbl(Portland['host_response_time'])
tabla5
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       1938    0.502333         0.502333
# 1  within a few hours        967    0.250648         0.752981
# 2        within a day        693    0.179627         0.932608
# 3  a few days or more        260    0.067392         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla6 = tabla5.drop(['percentage', 'cumulative_perc'], axis=1)
tabla6
# Out:
#    host_response_time  frequency
# 0      within an hour       1938
# 1  within a few hours        967
# 2        within a day        693
# 3  a few days or more        260

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro2 = tabla6[tabla6['frequency']!=592]
filtro2
# Out:
#    host_response_time  frequency
# 0      within an hour       1938
# 1  within a few hours        967
# 2        within a day        693
# 3  a few days or more        260

# %%
#Ajusto el indice de mi DataFrame
filtro_index2 = filtro2.set_index('host_response_time')
filtro_index2
# Out:
#                     frequency
# host_response_time
# within an hour           1938
# within a few hours        967
# within a day              693
# a few days or more        260

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_index2.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='host_response_time'>

# %%
tabla7 = freq_tbl(Portland['neighbourhood_cleansed'])
tabla7
# Out:
#                                neighbourhood_cleansed  frequency  percentage  \
# 0                        Ludwigsvorstadt-Isarvorstadt        496    0.128564
# 1                                         Maxvorstadt        312    0.080871
# 2                                       Au-Haidhausen        231    0.059876
# 3                                      Schwabing-West        209    0.054173
# 4                               Neuhausen-Nymphenburg        206    0.053396
# 5                                  Ramersdorf-Perlach        174    0.045101
# 6                                  Schwabing-Freimann        171    0.044323
# 7   Thalkirchen-Obersendling-Forstenried-Fürstenri...        164    0.042509
# 8                                   Sendling-Westpark        164    0.042509
# 9                                       Tudering-Riem        157    0.040695
# 10                                        Bogenhausen        157    0.040695
# 11                              Milbertshofen-Am Hart        145    0.037584
# 12                                        Obergiesing        144    0.037325
# 13                                     Altstadt-Lehel        132    0.034215
# 14                                           Sendling        121    0.031363
# 15                         Aubing-Lochhausen-Langwied        118    0.030586
# 16                            Untergiesing-Harlaching        115    0.029808
# 17                                   Schwanthalerhöhe        115    0.029808
# 18                                               Laim        111    0.028771
# 19                                 Pasing-Obermenzing        104    0.026957
# 20                                       Berg am Laim         89    0.023069
# 21                             Feldmoching-Hasenbergl         74    0.019181
# 22                                            Moosach         70    0.018144
# 23                                             Hadern         40    0.010368
# 24                                Allach-Untermenzing         39    0.010109
#
#     cumulative_perc
# 0          0.128564
# 1          0.209435
# 2          0.269311
# 3          0.323484
# 4          0.376879
# 5          0.421980
# 6          0.466304
# 7          0.508813
# 8          0.551322
# 9          0.592017
# 10         0.632711
# 11         0.670295
# 12         0.707621
# 13         0.741835
# 14         0.773199
# 15         0.803784
# 16         0.833593
# 17         0.863401
# 18         0.892172
# 19         0.919129
# 20         0.942198
# 21         0.961379
# 22         0.979523
# 23         0.989891
# 24         1.000000

# %%
#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
tabla7.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
tabla8 = freq_tbl(Portland['property_type'])
tabla8
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       1983    0.513997         0.513997
# 1          Private room in rental unit        835    0.216433         0.730430
# 2                         Entire condo        207    0.053655         0.784085
# 3                 Private room in home        167    0.043287         0.827372
# 4            Entire serviced apartment        166    0.043027         0.870399
# 5                Private room in condo        107    0.027735         0.898134
# 6                        Room in hotel         66    0.017107         0.915241
# 7                          Entire home         52    0.013478         0.928720
# 8            Private room in townhouse         50    0.012960         0.941680
# 9                          Entire loft         50    0.012960         0.954640
# 10                  Room in aparthotel         22    0.005702         0.960342
# 11              Room in boutique hotel         20    0.005184         0.965526
# 12                    Entire townhouse         13    0.003370         0.968896
# 13  Private room in serviced apartment         11    0.002851         0.971747
# 14   Private room in bed and breakfast          9    0.002333         0.974080
# 15          Private room in guesthouse          9    0.002333         0.976413
# 16          Shared room in rental unit          9    0.002333         0.978745
# 17                  Entire guest suite          7    0.001814         0.980560
# 18                        Entire villa          6    0.001555         0.982115
# 19                Private room in loft          6    0.001555         0.983670
# 20     Private room in casa particular          6    0.001555         0.985226
# 21                        Private room          5    0.001296         0.986522
# 22                   Entire guesthouse          5    0.001296         0.987818
# 23          Room in serviced apartment          4    0.001037         0.988854
# 24                  Shipping container          4    0.001037         0.989891
# 25                           Camper/RV          4    0.001037         0.990928
# 26       Private room in vacation home          3    0.000778         0.991706
# 27                           Tiny home          3    0.000778         0.992483
# 28                        Entire place          3    0.000778         0.993261
# 29                Entire vacation home          3    0.000778         0.994038
# 30                     Entire bungalow          3    0.000778         0.994816
# 31               Shared room in hostel          2    0.000518         0.995334
# 32         Private room in guest suite          2    0.000518         0.995853
# 33    Shared room in bed and breakfast          2    0.000518         0.996371
# 34               Private room in villa          2    0.000518         0.996890
# 35                 Shared room in home          2    0.000518         0.997408
# 36                        Entire cabin          1    0.000259         0.997667
# 37             Shared room in ice dome          1    0.000259         0.997926
# 38           Private room in farm stay          1    0.000259         0.998186
# 39                      Shepherd’s hut          1    0.000259         0.998445
# 40                         Shared room          1    0.000259         0.998704
# 41            Private room in bungalow          1    0.000259         0.998963
# 42                             Pension          1    0.000259         0.999222
# 43                Shared room in condo          1    0.000259         0.999482
# 44                                 Hut          1    0.000259         0.999741
# 45                                Tent          1    0.000259         1.000000

# %%
filtro3 = tabla8[(tabla8["frequency"] > 100)]
filtro3
# Out:
#                  property_type  frequency  percentage  cumulative_perc
# 0           Entire rental unit       1983    0.513997         0.513997
# 1  Private room in rental unit        835    0.216433         0.730430
# 2                 Entire condo        207    0.053655         0.784085
# 3         Private room in home        167    0.043287         0.827372
# 4    Entire serviced apartment        166    0.043027         0.870399
# 5        Private room in condo        107    0.027735         0.898134

# %%
#Ajusto el indice de mi DataFrame
filtro_index3 = filtro3.set_index('property_type')
filtro_index3
# Out:
#                              frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                1983    0.513997         0.513997
# Private room in rental unit        835    0.216433         0.730430
# Entire condo                       207    0.053655         0.784085
# Private room in home               167    0.043287         0.827372
# Entire serviced apartment          166    0.043027         0.870399
# Private room in condo              107    0.027735         0.898134

# %%
#Realizamos grafico de pastel de dataframe filtrado 
filtro_index3["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('property_type')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
tabla9 = freq_tbl(Portland['room_type'])
tabla9
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       2522    0.653707         0.653707
# 1     Private room       1303    0.337740         0.991446
# 2      Shared room         18    0.004666         0.996112
# 3       Hotel room         15    0.003888         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla10 = tabla9.drop(['percentage', 'cumulative_perc'], axis=1)
tabla10
# Out:
#          room_type  frequency
# 0  Entire home/apt       2522
# 1     Private room       1303
# 2      Shared room         18
# 3       Hotel room         15

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro4 = tabla9[tabla9['frequency'] > 30]
filtro4
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       2522    0.653707         0.653707
# 1     Private room       1303    0.337740         0.991446

# %%
#Ajusto el indice de mi DataFrame
filtro_index4 = filtro4.set_index('room_type')
filtro_index4
# Out:
#                  frequency  percentage  cumulative_perc
# room_type
# Entire home/apt       2522    0.653707         0.653707
# Private room          1303    0.337740         0.991446

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_index4.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='room_type'>

# %%
tabla11 = freq_tbl(Portland['amenities'])
tabla11
# Out:
#                                               amenities  frequency  \
# 0     ["Smoke alarm", "Fire extinguisher", "Dedicate...         12
# 1     ["Dryer", "Dishes and silverware", "Dedicated ...         11
# 2     ["Heating", "Coffee maker", "Self check-in", "...          9
# 3     ["Dryer", "Dishes and silverware", "Dedicated ...          7
# 4     ["Luggage dropoff allowed", "Heating", "Hot wa...          6
# ...                                                 ...        ...
# 3688  ["Hangers", "Hot water", "Washer", "Heating", ...          1
# 3689  ["Outdoor furniture", "Heating", "Hot water ke...          1
# 3690  ["Heating", "Hot water kettle", "Coffee maker"...          1
# 3691  ["Heating", "Single level home", "Lockbox", "S...          1
# 3692  ["Smoke alarm", "Air conditioning", "Lockbox",...          1
#
#       percentage  cumulative_perc
# 0       0.003110         0.003110
# 1       0.002851         0.005962
# 2       0.002333         0.008294
# 3       0.001814         0.010109
# 4       0.001555         0.011664
# ...          ...              ...
# 3688    0.000259         0.998963
# 3689    0.000259         0.999222
# 3690    0.000259         0.999482
# 3691    0.000259         0.999741
# 3692    0.000259         1.000000
#
# [3693 rows x 4 columns]

# %%
#Realizamos grafico de dispersion del dataframe filtrado
tabla11.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
tabla12 = freq_tbl(Portland['has_availability'])
tabla12
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t       3858         1.0              1.0

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla13 = tabla12.drop(['percentage', 'cumulative_perc'], axis=1)
tabla13
# Out:
#   has_availability  frequency
# 0                t       3858

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro5 = tabla12[tabla12['frequency'] > 1]
filtro5
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t       3858         1.0              1.0

# %%
#Ajusto el indice de mi DataFrame
filtro_index5 = filtro5.set_index('has_availability')
filtro_index5
# Out:
#                   frequency  percentage  cumulative_perc
# has_availability
# t                      3858         1.0              1.0

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index5.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('has availability')
plt.xlabel('Disponibilidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla14 = freq_tbl(Portland['first_review'])
tabla14
# Out:
#      first_review  frequency  percentage  cumulative_perc
# 0      22/09/2024         66    0.017107         0.017107
# 1      24/09/2023         60    0.015552         0.032659
# 2      17/09/2023         45    0.011664         0.044323
# 3      21/06/2024         42    0.010886         0.055210
# 4      23/09/2024         37    0.009590         0.064800
# ...           ...        ...         ...              ...
# 1524   04/10/2018          1    0.000259         0.998963
# 1525   24/10/2018          1    0.000259         0.999222
# 1526   16/07/2021          1    0.000259         0.999482
# 1527   04/01/2019          1    0.000259         0.999741
# 1528   29/01/2020          1    0.000259         1.000000
#
# [1529 rows x 4 columns]

# %%
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla15 = tabla14.drop(['percentage', 'cumulative_perc'], axis=1)
tabla15
# Out:
#      first_review  frequency
# 0      22/09/2024         66
# 1      24/09/2023         60
# 2      17/09/2023         45
# 3      21/06/2024         42
# 4      23/09/2024         37
# ...           ...        ...
# 1524   04/10/2018          1
# 1525   24/10/2018          1
# 1526   16/07/2021          1
# 1527   04/01/2019          1
# 1528   29/01/2020          1
#
# [1529 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro6 = tabla14[tabla14['frequency'] > 70]
filtro6
# Out:
# Empty DataFrame
# Columns: [first_review, frequency, percentage, cumulative_perc]
# Index: []

# %%
filtro_index6 = filtro6.set_index('first_review')
filtro_index6
# Out:
# Empty DataFrame
# Columns: [frequency, percentage, cumulative_perc]
# Index: []

# %%
filtro_index6.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('Primeras vistas')
plt.xlabel('Fechas')
plt.ylabel('Frecuencia')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 filtro_index6.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
#       2 plt.title('Primeras vistas')
#       3 plt.xlabel('Fechas')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_matplotlib\core.py:508, in MPLPlot.generate(self)
#     506 for ax in self.axes:
#     507     self._post_plot_logic_common(ax)
# --> 508     self._post_plot_logic(ax, self.data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_matplotlib\core.py:1972, in BarPlot._post_plot_logic(self, ax, data)
#    1969 else:
#    1970     str_index = [pprint_thing(key) for key in range(data.shape[0])]
# -> 1972 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1973 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1975 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
tabla16 = freq_tbl(Portland['instant_bookable'])
tabla16
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       3111    0.806376         0.806376
# 1                t        747    0.193624         1.000000

# %%
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla17 = tabla16.drop(['percentage', 'cumulative_perc'], axis=1)
tabla17
# Out:
#   instant_bookable  frequency
# 0                f       3111
# 1                t        747

# %%
#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro7 = tabla16[tabla16['frequency'] > 1000]
filtro7
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       3111    0.806376         0.806376

# %%
filtro_index7 = filtro7.set_index('instant_bookable')
filtro_index7
# Out:
#                   frequency  percentage  cumulative_perc
# instant_bookable
# f                      3111    0.806376         0.806376

# %%
#Realizamos grafico de pastel de dataframe filtrado 
filtro_index7["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('instant_bookable')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla18 = freq_tbl(Portland['host_verifications'])
tabla18
# Out:
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']       3023    0.783567         0.783567
# 1  ['email', 'phone', 'work_email']        433    0.112234         0.895801
# 2                         ['phone']        395    0.102385         0.998186
# 3           ['phone', 'work_email']          7    0.001814         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla19 = tabla18.drop(['percentage', 'cumulative_perc'], axis=1)
tabla19
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']       3023
# 1  ['email', 'phone', 'work_email']        433
# 2                         ['phone']        395
# 3           ['phone', 'work_email']          7

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
tabla20 = freq_tbl(Portland['last_review'])
tabla20
# Out:
#     last_review  frequency  percentage  cumulative_perc
# 0    01/09/2024        297    0.076983         0.076983
# 1    22/09/2024        269    0.069725         0.146708
# 2    23/09/2024        213    0.055210         0.201918
# 3    25/08/2024        142    0.036807         0.238725
# 4    18/08/2024        105    0.027216         0.265941
# ..          ...        ...         ...              ...
# 507  18/09/2020          1    0.000259         0.998963
# 508  21/09/2022          1    0.000259         0.999222
# 509  14/05/2023          1    0.000259         0.999482
# 510  20/11/2023          1    0.000259         0.999741
# 511  05/06/2024          1    0.000259         1.000000
#
# [512 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla21 = tabla20.drop(['percentage', 'cumulative_perc'], axis=1)
tabla21
# Out:
#     last_review  frequency
# 0    01/09/2024        297
# 1    22/09/2024        269
# 2    23/09/2024        213
# 3    25/08/2024        142
# 4    18/08/2024        105
# ..          ...        ...
# 507  18/09/2020          1
# 508  21/09/2022          1
# 509  14/05/2023          1
# 510  20/11/2023          1
# 511  05/06/2024          1
#
# [512 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro8 = tabla20[tabla20['frequency'] > 100]
filtro8
# Out:
#   last_review  frequency  percentage  cumulative_perc
# 0  01/09/2024        297    0.076983         0.076983
# 1  22/09/2024        269    0.069725         0.146708
# 2  23/09/2024        213    0.055210         0.201918
# 3  25/08/2024        142    0.036807         0.238725
# 4  18/08/2024        105    0.027216         0.265941
# 5  24/09/2024        105    0.027216         0.293157
# 6  02/09/2024        103    0.026698         0.319855

# %%
#Ajusto el indice de mi DataFrame
filtro_index8 = filtro8.set_index('last_review')
filtro_index8
# Out:
#              frequency  percentage  cumulative_perc
# last_review
# 01/09/2024         297    0.076983         0.076983
# 22/09/2024         269    0.069725         0.146708
# 23/09/2024         213    0.055210         0.201918
# 25/08/2024         142    0.036807         0.238725
# 18/08/2024         105    0.027216         0.265941
# 24/09/2024         105    0.027216         0.293157
# 02/09/2024         103    0.026698         0.319855

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index8.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('última revsión')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland['availability_30'] = Portland['availability_30'].astype('category')
tabla22 = freq_tbl(Portland['availability_30'])
tabla22
# Out:
#    availability_30  frequency  percentage  cumulative_perc
# 0                0        606    0.157076         0.157076
# 1                2        222    0.057543         0.214619
# 2                1        214    0.055469         0.270088
# 3                4        188    0.048730         0.318818
# 4                5        166    0.043027         0.361846
# 5                3        159    0.041213         0.403059
# 6                6        149    0.038621         0.441680
# 7               17        127    0.032919         0.474598
# 8               18        121    0.031363         0.505962
# 9                9        118    0.030586         0.536547
# 10              19        112    0.029031         0.565578
# 11              20        109    0.028253         0.593831
# 12               8        109    0.028253         0.622084
# 13              15        106    0.027475         0.649559
# 14               7        106    0.027475         0.677035
# 15              21        104    0.026957         0.703992
# 16              22        103    0.026698         0.730689
# 17              16        101    0.026179         0.756869
# 18              11         96    0.024883         0.781752
# 19              14         95    0.024624         0.806376
# 20              10         92    0.023847         0.830223
# 21              12         88    0.022810         0.853033
# 22              13         86    0.022291         0.875324
# 23              23         83    0.021514         0.896838
# 24              25         81    0.020995         0.917833
# 25              24         74    0.019181         0.937014
# 26              26         64    0.016589         0.953603
# 27              27         54    0.013997         0.967600
# 28              29         44    0.011405         0.979005
# 29              28         43    0.011146         0.990150
# 30              30         38    0.009850         1.000000

# %%
#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
tabla22.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Portland['latitude'] = Portland['latitude'].astype('category')
tabla23 = freq_tbl(Portland['latitude'])
tabla23
# Out:
#        latitude  frequency  percentage  cumulative_perc
# 0     48.139461         34    0.008813         0.008813
# 1     48.139463         15    0.003888         0.012701
# 2     48.097408         10    0.002592         0.015293
# 3     48.100000          8    0.002074         0.017367
# 4     48.138053          7    0.001814         0.019181
# ...         ...        ...         ...              ...
# 3418  48.127429          1    0.000259         0.998963
# 3419  48.127443          1    0.000259         0.999222
# 3420  48.127444          1    0.000259         0.999482
# 3421  48.127500          1    0.000259         0.999741
# 3422  48.217760          1    0.000259         1.000000
#
# [3423 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla24 = tabla23.drop(['percentage', 'cumulative_perc'], axis=1)
tabla24
# Out:
#        latitude  frequency
# 0     48.139461         34
# 1     48.139463         15
# 2     48.097408         10
# 3     48.100000          8
# 4     48.138053          7
# ...         ...        ...
# 3418  48.127429          1
# 3419  48.127443          1
# 3420  48.127444          1
# 3421  48.127500          1
# 3422  48.217760          1
#
# [3423 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro9 = tabla23[tabla23['frequency'] > 10]
filtro9
# Out:
#     latitude  frequency  percentage  cumulative_perc
# 0  48.139461         34    0.008813         0.008813
# 1  48.139463         15    0.003888         0.012701

# %%
#Ajusto el indice de mi DataFrame
filtro_index9 = filtro9.set_index('latitude')
filtro_index9
# Out:
#            frequency  percentage  cumulative_perc
# latitude
# 48.139461         34    0.008813         0.008813
# 48.139463         15    0.003888         0.012701

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index9.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Latitud')
plt.xlabel('latitud')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland['longitude'] = Portland['longitude'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla25 = freq_tbl(Portland['longitude'])
tabla25
# Out:
#       longitude  frequency  percentage  cumulative_perc
# 0     11.409209         34    0.008813         0.008813
# 1     11.409209         15    0.003888         0.012701
# 2     11.527628         10    0.002592         0.015293
# 3     11.561349          7    0.001814         0.017107
# 4     11.532753          6    0.001555         0.018663
# ...         ...        ...         ...              ...
# 3504  11.550160          1    0.000259         0.998963
# 3505  11.550319          1    0.000259         0.999222
# 3506  11.550339          1    0.000259         0.999482
# 3507  11.550360          1    0.000259         0.999741
# 3508  11.712699          1    0.000259         1.000000
#
# [3509 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla26 = tabla25.drop(['percentage', 'cumulative_perc'], axis=1)
tabla26
# Out:
#       longitude  frequency
# 0     11.409209         34
# 1     11.409209         15
# 2     11.527628         10
# 3     11.561349          7
# 4     11.532753          6
# ...         ...        ...
# 3504  11.550160          1
# 3505  11.550319          1
# 3506  11.550339          1
# 3507  11.550360          1
# 3508  11.712699          1
#
# [3509 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro10 = tabla26[tabla26['frequency'] > 8]
filtro10
# Out:
#    longitude  frequency
# 0  11.409209         34
# 1  11.409209         15
# 2  11.527628         10

# %%
#Ajusto el indice de mi DataFrame
filtro_index10 = filtro10.set_index('longitude')
filtro_index10
# Out:
#            frequency
# longitude
# 11.409209         34
# 11.409209         15
# 11.527628         10

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index10.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "pink")
plt.title('Longitud')
plt.xlabel('longitudes')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland['host_id'] = Portland['host_id'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla27 = freq_tbl(Portland['host_id'])
tabla27
# Out:
#         host_id  frequency  percentage  cumulative_perc
# 0     376961462         72    0.018663         0.018663
# 1      51557252         23    0.005962         0.024624
# 2     512924239         17    0.004406         0.029031
# 3     164225004         15    0.003888         0.032919
# 4       7901771         15    0.003888         0.036807
# ...         ...        ...         ...              ...
# 2998   44432463          1    0.000259         0.998963
# 2999   44556787          1    0.000259         0.999222
# 3000   44557015          1    0.000259         0.999482
# 3001   44750066          1    0.000259         0.999741
# 3002  651048303          1    0.000259         1.000000
#
# [3003 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla28 = tabla27.drop(['percentage', 'cumulative_perc'], axis=1)
tabla28
# Out:
#         host_id  frequency
# 0     376961462         72
# 1      51557252         23
# 2     512924239         17
# 3     164225004         15
# 4       7901771         15
# ...         ...        ...
# 2998   44432463          1
# 2999   44556787          1
# 3000   44557015          1
# 3001   44750066          1
# 3002  651048303          1
#
# [3003 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro11 = tabla27[tabla27['frequency'] > 20]
filtro11
# Out:
#      host_id  frequency  percentage  cumulative_perc
# 0  376961462         72    0.018663         0.018663
# 1   51557252         23    0.005962         0.024624

# %%
#Ajusto el indice de mi DataFrame
filtro_index11 = filtro11.set_index('host_id')
filtro_index11
# Out:
#            frequency  percentage  cumulative_perc
# host_id
# 376961462         72    0.018663         0.018663
# 51557252          23    0.005962         0.024624

# %%
#Realizamos grafico de pastel de dataframe filtrado 
filtro_index11["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('host_id')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland['review_scores_rating'] = Portland['review_scores_rating'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla29 = freq_tbl(Portland['review_scores_rating'])
tabla29
# Out:
#     review_scores_rating  frequency  percentage  cumulative_perc
# 0                   5.00       1331    0.344997         0.344997
# 1                   4.80        145    0.037584         0.382582
# 2                   4.50        120    0.031104         0.413686
# 3                   4.67        111    0.028771         0.442457
# 4                   4.00        109    0.028253         0.470710
# ..                   ...        ...         ...              ...
# 100                 3.98          1    0.000259         0.998963
# 101                 4.05          1    0.000259         0.999222
# 102                 4.21          1    0.000259         0.999482
# 103                 4.34          1    0.000259         0.999741
# 104                 3.93          1    0.000259         1.000000
#
# [105 rows x 4 columns]

# %%
#Realizamos grafico de dispersion del dataframe filtrado
tabla29.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Portland['minimum_nights'] = Portland['minimum_nights'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla30 = freq_tbl(Portland['minimum_nights'])
tabla30
# Out:
#    minimum_nights  frequency  percentage  cumulative_perc
# 0             1.0       1552    0.402281         0.402281
# 1             2.0       1071    0.277605         0.679886
# 2             3.0        601    0.155780         0.835666
# 3             5.0        166    0.043027         0.878694
# 4             4.0        135    0.034992         0.913686
# 5             7.0         85    0.022032         0.935718
# 6             6.0         60    0.015552         0.951270
# 7            14.0         38    0.009850         0.961120
# 8            30.0         37    0.009590         0.970710
# 9            10.0         22    0.005702         0.976413
# 10           28.0         19    0.004925         0.981337
# 11           20.0         15    0.003888         0.985226
# 12            8.0         10    0.002592         0.987818
# 13           12.0          8    0.002074         0.989891
# 14           25.0          8    0.002074         0.991965
# 15           15.0          6    0.001555         0.993520
# 16           21.0          4    0.001037         0.994557
# 17           31.0          3    0.000778         0.995334
# 18           40.0          2    0.000518         0.995853
# 19           29.0          2    0.000518         0.996371
# 20           22.0          2    0.000518         0.996890
# 21           24.0          2    0.000518         0.997408
# 22           26.0          2    0.000518         0.997926
# 23           27.0          1    0.000259         0.998186
# 24           16.0          1    0.000259         0.998445
# 25           23.0          1    0.000259         0.998704
# 26           18.0          1    0.000259         0.998963
# 27           13.0          1    0.000259         0.999222
# 28           11.0          1    0.000259         0.999482
# 29            9.0          1    0.000259         0.999741
# 30           45.0          1    0.000259         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla31 = tabla30.drop(['percentage', 'cumulative_perc'], axis=1)
tabla31
# Out:
#    minimum_nights  frequency
# 0             1.0       1552
# 1             2.0       1071
# 2             3.0        601
# 3             5.0        166
# 4             4.0        135
# 5             7.0         85
# 6             6.0         60
# 7            14.0         38
# 8            30.0         37
# 9            10.0         22
# 10           28.0         19
# 11           20.0         15
# 12            8.0         10
# 13           12.0          8
# 14           25.0          8
# 15           15.0          6
# 16           21.0          4
# 17           31.0          3
# 18           40.0          2
# 19           29.0          2
# 20           22.0          2
# 21           24.0          2
# 22           26.0          2
# 23           27.0          1
# 24           16.0          1
# 25           23.0          1
# 26           18.0          1
# 27           13.0          1
# 28           11.0          1
# 29            9.0          1
# 30           45.0          1

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro12 = tabla30[tabla30['frequency'] > 8]
filtro12
# Out:
#    minimum_nights  frequency  percentage  cumulative_perc
# 0             1.0       1552    0.402281         0.402281
# 1             2.0       1071    0.277605         0.679886
# 2             3.0        601    0.155780         0.835666
# 3             5.0        166    0.043027         0.878694
# 4             4.0        135    0.034992         0.913686
# 5             7.0         85    0.022032         0.935718
# 6             6.0         60    0.015552         0.951270
# 7            14.0         38    0.009850         0.961120
# 8            30.0         37    0.009590         0.970710
# 9            10.0         22    0.005702         0.976413
# 10           28.0         19    0.004925         0.981337
# 11           20.0         15    0.003888         0.985226
# 12            8.0         10    0.002592         0.987818

# %%
#Ajusto el indice de mi DataFrame
filtro_index12 = filtro12.set_index('minimum_nights')
filtro_index12
# Out:
#                 frequency  percentage  cumulative_perc
# minimum_nights
# 1.0                  1552    0.402281         0.402281
# 2.0                  1071    0.277605         0.679886
# 3.0                   601    0.155780         0.835666
# 5.0                   166    0.043027         0.878694
# 4.0                   135    0.034992         0.913686
# 7.0                    85    0.022032         0.935718
# 6.0                    60    0.015552         0.951270
# 14.0                   38    0.009850         0.961120
# 30.0                   37    0.009590         0.970710
# 10.0                   22    0.005702         0.976413
# 28.0                   19    0.004925         0.981337
# 20.0                   15    0.003888         0.985226
# 8.0                    10    0.002592         0.987818

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro_index12["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
Portland['maximum_nights'] = Portland['maximum_nights'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla32 = freq_tbl(Portland['maximum_nights'])
tabla32
# Out:
#     maximum_nights  frequency  percentage  cumulative_perc
# 0              365       1227    0.318040         0.318040
# 1             1125        626    0.162260         0.480301
# 2               30        252    0.065319         0.545619
# 3               14        183    0.047434         0.593053
# 4                7        137    0.035511         0.628564
# ..             ...        ...         ...              ...
# 113            182          1    0.000259         0.998963
# 114            183          1    0.000259         0.999222
# 115             54          1    0.000259         0.999482
# 116            190          1    0.000259         0.999741
# 117             26          1    0.000259         1.000000
#
# [118 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla33 = tabla32.drop(['percentage', 'cumulative_perc'], axis=1)
tabla33
# Out:
#     maximum_nights  frequency
# 0              365       1227
# 1             1125        626
# 2               30        252
# 3               14        183
# 4                7        137
# ..             ...        ...
# 113            182          1
# 114            183          1
# 115             54          1
# 116            190          1
# 117             26          1
#
# [118 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro13 = tabla32[tabla32['frequency'] > 100]
filtro13
# Out:
#   maximum_nights  frequency  percentage  cumulative_perc
# 0            365       1227    0.318040         0.318040
# 1           1125        626    0.162260         0.480301
# 2             30        252    0.065319         0.545619
# 3             14        183    0.047434         0.593053
# 4              7        137    0.035511         0.628564
# 5            180        137    0.035511         0.664075
# 6             90        137    0.035511         0.699585

# %%
#Ajusto el indice de mi DataFrame
filtro_index13 = filtro13.set_index('maximum_nights')
filtro_index13
# Out:
#                 frequency  percentage  cumulative_perc
# maximum_nights
# 365                  1227    0.318040         0.318040
# 1125                  626    0.162260         0.480301
# 30                    252    0.065319         0.545619
# 14                    183    0.047434         0.593053
# 7                     137    0.035511         0.628564
# 180                   137    0.035511         0.664075
# 90                    137    0.035511         0.699585

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_index13.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='maximum_nights'>

# %% [markdown]
# Determinacion de clases para datos agrupados para 17 variables

# %%
#Corroboramos valores nulos 
valores_nulos = Portland.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0.1                                    0
# host_since                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_verifications                              0
# neighbourhood_cleansed                          0
# property_type                                   0
# room_type                                       0
# bathrooms_text                                  0
# amenities                                       0
# price                                           0
# has_availability                                0
# first_review                                    0
# last_review                                     0
# instant_bookable                                0
# host_id                                         0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# dtype: int64

# %%
Portland['availability_365'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   int64
# dtypes: int64(1)
# memory usage: 30.3 KB

# %%
Min = Portland['availability_365'].min()  
Max = Portland['availability_365'].max()  
Limites = [Min,Max]
Limites
# Out:
# [0, 365]

# %%
R = Max - Min
R
# Out:
# 365

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 26.14231406429128

# %%
# Ver resultado
intervalos = np.linspace(0.0, 365, 14) #Número de clases más uno
intervalos
# Out:
# array([  0.        ,  28.07692308,  56.15384615,  84.23076923,
#        112.30769231, 140.38461538, 168.46153846, 196.53846154,
#        224.61538462, 252.69230769, 280.76923077, 308.84615385,
#        336.92307692, 365.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
Portland["availability_365"] = pd.cut(x = Portland["availability_365"], bins = intervalos, labels = categorias)
Portland["availability_365"]
# Out:
# 0        Categoría7
# 1        Categoría4
# 2        Categoría2
# 3        Categoría6
# 4        Categoría2
#            ...
# 3853     Categoría6
# 3854    Categoria13
# 3855     Categoría1
# 3856    Categoría12
# 3857     Categoría1
# Name: availability_365, Length: 3858, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_1 = freq_tbl(Portland['availability_365'])
variable_1
# Out:
#    availability_365  frequency  percentage  cumulative_perc
# 0        Categoría1        773    0.200363         0.202303
# 1        Categoría3        497    0.128823         0.332374
# 2       Categoria13        378    0.097978         0.431301
# 3        Categoría2        374    0.096941         0.529181
# 4       Categoría10        308    0.079834         0.609788
# 5        Categoría6        261    0.067652         0.678095
# 6        Categoría4        249    0.064541         0.743261
# 7        Categoría7        219    0.056765         0.800576
# 8       Categoría12        190    0.049248         0.850301
# 9        Categoría9        181    0.046916         0.897671
# 10       Categoría5        156    0.040435         0.938498
# 11       Categoría8        125    0.032400         0.971212
# 12      Categoría11        110    0.028512         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_1_2 = variable_1.drop(['percentage', 'cumulative_perc'], axis=1)
variable_1_2
# Out:
#    availability_365  frequency
# 0        Categoría1        773
# 1        Categoría3        497
# 2       Categoria13        378
# 3        Categoría2        374
# 4       Categoría10        308
# 5        Categoría6        261
# 6        Categoría4        249
# 7        Categoría7        219
# 8       Categoría12        190
# 9        Categoría9        181
# 10       Categoría5        156
# 11       Categoría8        125
# 12      Categoría11        110

# %%
filtro_1 = variable_1_2[variable_1_2['frequency'] > 100]
filtro_1
# Out:
#    availability_365  frequency
# 0        Categoría1        773
# 1        Categoría3        497
# 2       Categoria13        378
# 3        Categoría2        374
# 4       Categoría10        308
# 5        Categoría6        261
# 6        Categoría4        249
# 7        Categoría7        219
# 8       Categoría12        190
# 9        Categoría9        181
# 10       Categoría5        156
# 11       Categoría8        125
# 12      Categoría11        110

# %%
#Ajusto el indice de mi DataFrame
filtro_i = filtro_1.set_index("availability_365")
filtro_i
# Out:
#                   frequency
# availability_365
# Categoría1              773
# Categoría3              497
# Categoria13             378
# Categoría2              374
# Categoría10             308
# Categoría6              261
# Categoría4              249
# Categoría7              219
# Categoría12             190
# Categoría9              181
# Categoría5              156
# Categoría8              125
# Categoría11             110

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "orange")
plt.title('Disponible 365')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland['number_of_reviews'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland['number_of_reviews'].min()  
Max = Portland['number_of_reviews'].max()  
Limites = [Min,Max]
Limites
# Out:
# [1.0, 357.0]

# %%
R = Max - Min
R
# Out:
# 356.0

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 25.49770905996629

# %%
# Ver resultado
intervalos = np.linspace(0.0, 42.0, 14) #Número de clases más uno
intervalos
# Out:
# array([ 0.        ,  3.23076923,  6.46153846,  9.69230769, 12.92307692,
#        16.15384615, 19.38461538, 22.61538462, 25.84615385, 29.07692308,
#        32.30769231, 35.53846154, 38.76923077, 42.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
Portland["number_of_reviews"] = pd.cut(x = Portland["number_of_reviews"], bins = intervalos, labels = categorias)
Portland["number_of_reviews"]
# Out:
# 0               NaN
# 1               NaN
# 2       Categoria13
# 3       Categoría10
# 4               NaN
#            ...
# 3853     Categoría1
# 3854     Categoría1
# 3855     Categoría1
# 3856     Categoría1
# 3857     Categoría1
# Name: number_of_reviews, Length: 3858, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_2 = freq_tbl(Portland['number_of_reviews'])
variable_2
# Out:
#    number_of_reviews  frequency  percentage  cumulative_perc
# 0         Categoría1        985    0.255314          0.31520
# 1         Categoría2        517    0.134007          0.48064
# 2         Categoría3        350    0.090721          0.59264
# 3         Categoría5        252    0.065319          0.67328
# 4         Categoría4        248    0.064282          0.75264
# 5         Categoría6        147    0.038103          0.79968
# 6        Categoría10        137    0.035511          0.84352
# 7         Categoría7        120    0.031104          0.88192
# 8         Categoría9        101    0.026179          0.91424
# 9         Categoría8         87    0.022551          0.94208
# 10       Categoría11         67    0.017367          0.96352
# 11       Categoria13         62    0.016071          0.98336
# 12       Categoría12         52    0.013478          1.00000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_2_2 = variable_2.drop(['percentage', 'cumulative_perc'], axis=1)
variable_2_2
# Out:
#    number_of_reviews  frequency
# 0         Categoría1        985
# 1         Categoría2        517
# 2         Categoría3        350
# 3         Categoría5        252
# 4         Categoría4        248
# 5         Categoría6        147
# 6        Categoría10        137
# 7         Categoría7        120
# 8         Categoría9        101
# 9         Categoría8         87
# 10       Categoría11         67
# 11       Categoria13         62
# 12       Categoría12         52

# %%
filtro_2 = variable_2_2[variable_2_2['frequency'] > 100]
filtro_2
# Out:
#   number_of_reviews  frequency
# 0        Categoría1        985
# 1        Categoría2        517
# 2        Categoría3        350
# 3        Categoría5        252
# 4        Categoría4        248
# 5        Categoría6        147
# 6       Categoría10        137
# 7        Categoría7        120
# 8        Categoría9        101

# %%
#Ajusto el indice de mi DataFrame
filtro_i2 = filtro_2.set_index("number_of_reviews")
filtro_i2
# Out:
#                    frequency
# number_of_reviews
# Categoría1               985
# Categoría2               517
# Categoría3               350
# Categoría5               252
# Categoría4               248
# Categoría6               147
# Categoría10              137
# Categoría7               120
# Categoría9               101

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i2.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Numero de reseñas')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland['review_scores_location'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland['review_scores_location'].min()  
Max = Portland['review_scores_location'].max()  
Limites = [Min,Max]
Limites
# Out:
# [3.75, 5.0]

# %%
R = Max - Min
R
# Out:
# 1.25

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.08952847282291534

# %%
# Ver resultado
intervalos = np.linspace(4.6, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.6       , 4.63076923, 4.66153846, 4.69230769, 4.72307692,
#        4.75384615, 4.78461538, 4.81538462, 4.84615385, 4.87692308,
#        4.90769231, 4.93846154, 4.96923077, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
Portland["review_scores_location"] = pd.cut(x = Portland["review_scores_location"], bins = intervalos, labels = categorias)
Portland["review_scores_location"]
# Out:
# 0        Categoría6
# 1        Categoría2
# 2               NaN
# 3        Categoría6
# 4        Categoría8
#            ...
# 3853    Categoria13
# 3854    Categoria13
# 3855     Categoría7
# 3856    Categoria13
# 3857    Categoria13
# Name: review_scores_location, Length: 3858, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_3 = freq_tbl(Portland['review_scores_location'])
variable_3
# Out:
#    review_scores_location  frequency  percentage  cumulative_perc
# 0             Categoria13       1293    0.335148         0.401304
# 1             Categoría10        250    0.064800         0.478895
# 2              Categoría7        224    0.058061         0.548417
# 3              Categoría5        202    0.052359         0.611111
# 4              Categoría8        202    0.052359         0.673805
# 5              Categoría3        189    0.048989         0.732464
# 6              Categoría9        186    0.048212         0.790192
# 7             Categoría11        169    0.043805         0.842644
# 8             Categoría12        157    0.040695         0.891372
# 9              Categoría6        131    0.033955         0.932030
# 10             Categoría4        106    0.027475         0.964929
# 11             Categoría1         62    0.016071         0.984171
# 12             Categoría2         51    0.013219         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_3_2 = variable_3.drop(['percentage', 'cumulative_perc'], axis=1)
variable_3_2
# Out:
#    review_scores_location  frequency
# 0             Categoria13       1293
# 1             Categoría10        250
# 2              Categoría7        224
# 3              Categoría5        202
# 4              Categoría8        202
# 5              Categoría3        189
# 6              Categoría9        186
# 7             Categoría11        169
# 8             Categoría12        157
# 9              Categoría6        131
# 10             Categoría4        106
# 11             Categoría1         62
# 12             Categoría2         51

# %%
filtro_3 = variable_3_2[variable_3_2['frequency'] > 100]
filtro_3
# Out:
#    review_scores_location  frequency
# 0             Categoria13       1293
# 1             Categoría10        250
# 2              Categoría7        224
# 3              Categoría5        202
# 4              Categoría8        202
# 5              Categoría3        189
# 6              Categoría9        186
# 7             Categoría11        169
# 8             Categoría12        157
# 9              Categoría6        131
# 10             Categoría4        106

# %%
#Ajusto el indice de mi DataFrame
filtro_i3 = filtro_3.set_index("review_scores_location")
filtro_i3
# Out:
#                         frequency
# review_scores_location
# Categoria13                  1293
# Categoría10                   250
# Categoría7                    224
# Categoría5                    202
# Categoría8                    202
# Categoría3                    189
# Categoría9                    186
# Categoría11                   169
# Categoría12                   157
# Categoría6                    131
# Categoría4                    106

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i3.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Puntuacion de locacion')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland['review_scores_value'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland['review_scores_value'].min()  
Max = Portland['review_scores_value'].max()  
Limites = [Min,Max]
Limites
# Out:
# [3.33, 5.0]

# %%
R = Max - Min
R
# Out:
# 1.67

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
# Ver resultado
intervalos = np.linspace(4.23, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.23      , 4.28923077, 4.34846154, 4.40769231, 4.46692308,
#        4.52615385, 4.58538462, 4.64461538, 4.70384615, 4.76307692,
#        4.82230769, 4.88153846, 4.94076923, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
Portland['review_scores_value'] = pd.cut(x = Portland['review_scores_value'], bins = intervalos, labels = categorias)
Portland['review_scores_value']
# Out:
# 0        Categoría9
# 1        Categoría7
# 2        Categoría4
# 3       Categoría12
# 4       Categoría10
#            ...
# 3853    Categoria13
# 3854    Categoria13
# 3855     Categoría7
# 3856    Categoria13
# 3857    Categoria13
# Name: review_scores_value, Length: 3858, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_4 = freq_tbl(Portland['review_scores_value'])
variable_4
# Out:
#    review_scores_value  frequency  percentage  cumulative_perc
# 0          Categoria13        775    0.200881         0.224768
# 1           Categoría9        367    0.095127         0.331206
# 2           Categoría7        335    0.086833         0.428364
# 3           Categoría8        333    0.086314         0.524942
# 4          Categoría10        325    0.084241         0.619200
# 5          Categoría11        286    0.074132         0.702146
# 6           Categoría5        276    0.071540         0.782193
# 7           Categoría6        177    0.045879         0.833527
# 8          Categoría12        175    0.045360         0.884281
# 9           Categoría4        127    0.032919         0.921114
# 10          Categoría2        116    0.030067         0.954756
# 11          Categoría3        100    0.025920         0.983759
# 12          Categoría1         56    0.014515         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_4_2 = variable_4.drop(['percentage', 'cumulative_perc'], axis=1)
variable_4_2
# Out:
#    review_scores_value  frequency
# 0          Categoria13        775
# 1           Categoría9        367
# 2           Categoría7        335
# 3           Categoría8        333
# 4          Categoría10        325
# 5          Categoría11        286
# 6           Categoría5        276
# 7           Categoría6        177
# 8          Categoría12        175
# 9           Categoría4        127
# 10          Categoría2        116
# 11          Categoría3        100
# 12          Categoría1         56

# %%
filtro_4 = variable_4_2[variable_4_2['frequency'] > 100]
filtro_4
# Out:
#    review_scores_value  frequency
# 0          Categoria13        775
# 1           Categoría9        367
# 2           Categoría7        335
# 3           Categoría8        333
# 4          Categoría10        325
# 5          Categoría11        286
# 6           Categoría5        276
# 7           Categoría6        177
# 8          Categoría12        175
# 9           Categoría4        127
# 10          Categoría2        116

# %%
#Ajusto el indice de mi DataFrame
filtro_i4 = filtro_4.set_index("review_scores_value")
filtro_i4
# Out:
#                      frequency
# review_scores_value
# Categoria13                775
# Categoría9                 367
# Categoría7                 335
# Categoría8                 333
# Categoría10                325
# Categoría11                286
# Categoría5                 276
# Categoría6                 177
# Categoría12                175
# Categoría4                 127
# Categoría2                 116

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i4.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_value'>

# %%
Portland['reviews_per_month'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland['reviews_per_month'].min()  
Max = Portland['reviews_per_month'].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.01, 7.62]

# %%
R = Max - Min
R
# Out:
# 7.61

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.5450493425459086

# %%
# Ver resultado
intervalos = np.linspace(0.01, 2.34, 14) #Número de clases más uno
intervalos
# Out:
# array([0.01      , 0.18923077, 0.36846154, 0.54769231, 0.72692308,
#        0.90615385, 1.08538462, 1.26461538, 1.44384615, 1.62307692,
#        1.80230769, 1.98153846, 2.16076923, 2.34      ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
Portland['reviews_per_month'] = pd.cut(x = Portland['reviews_per_month'], bins = intervalos, labels = categorias)
Portland['reviews_per_month']
# Out:
# 0       Categoría5
# 1       Categoría3
# 2       Categoría2
# 3              NaN
# 4       Categoría5
#            ...
# 3853    Categoría6
# 3854    Categoría6
# 3855    Categoría6
# 3856    Categoría6
# 3857           NaN
# Name: reviews_per_month, Length: 3858, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_5 = freq_tbl(Portland['reviews_per_month'])
variable_5
# Out:
#    reviews_per_month  frequency  percentage  cumulative_perc
# 0         Categoría2        544    0.141006         0.169207
# 1         Categoría1        531    0.137636         0.334370
# 2         Categoría6        357    0.092535         0.445412
# 3         Categoría3        351    0.090980         0.554588
# 4         Categoría4        318    0.082426         0.653499
# 5         Categoría5        219    0.056765         0.721617
# 6         Categoría8        193    0.050026         0.781649
# 7         Categoría9        156    0.040435         0.830171
# 8         Categoría7        153    0.039658         0.877760
# 9        Categoría12        124    0.032141         0.916330
# 10       Categoría10        102    0.026439         0.948056
# 11       Categoría11         96    0.024883         0.977916
# 12       Categoria13         71    0.018403         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_5_2 = variable_5.drop(['percentage', 'cumulative_perc'], axis=1)
variable_5_2
# Out:
#    reviews_per_month  frequency
# 0         Categoría2        544
# 1         Categoría1        531
# 2         Categoría6        357
# 3         Categoría3        351
# 4         Categoría4        318
# 5         Categoría5        219
# 6         Categoría8        193
# 7         Categoría9        156
# 8         Categoría7        153
# 9        Categoría12        124
# 10       Categoría10        102
# 11       Categoría11         96
# 12       Categoria13         71

# %%
filtro_5 = variable_5_2[variable_1_2['frequency'] > 100]
filtro_5
# Out:
#    reviews_per_month  frequency
# 0         Categoría2        544
# 1         Categoría1        531
# 2         Categoría6        357
# 3         Categoría3        351
# 4         Categoría4        318
# 5         Categoría5        219
# 6         Categoría8        193
# 7         Categoría9        156
# 8         Categoría7        153
# 9        Categoría12        124
# 10       Categoría10        102
# 11       Categoría11         96
# 12       Categoria13         71

# %%
#Ajusto el indice de mi DataFrame
filtro_i5 = filtro_5.set_index('reviews_per_month')
filtro_i5
# Out:
#                    frequency
# reviews_per_month
# Categoría2               544
# Categoría1               531
# Categoría6               357
# Categoría3               351
# Categoría4               318
# Categoría5               219
# Categoría8               193
# Categoría9               156
# Categoría7               153
# Categoría12              124
# Categoría10              102
# Categoría11               96
# Categoria13               71

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i5.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='reviews_per_month'>

# %%
Portland['review_scores_communication'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland['review_scores_communication'].min()  
Max = Portland['review_scores_communication'].max()  
Limites = [Min,Max]
Limites
# Out:
# [3.88, 5.0]

# %%
R = Max - Min
R
# Out:
# 1.12

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.08021751164933216

# %%
# Ver resultado
intervalos = np.linspace(4.76, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.76      , 4.77846154, 4.79692308, 4.81538462, 4.83384615,
#        4.85230769, 4.87076923, 4.88923077, 4.90769231, 4.92615385,
#        4.94461538, 4.96307692, 4.98153846, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
Portland['review_scores_communication'] = pd.cut(x = Portland['review_scores_communication'], bins = intervalos, labels = categorias)
Portland['review_scores_communication']
# Out:
# 0       Categoría10
# 1       Categoria13
# 2        Categoría3
# 3       Categoría12
# 4        Categoría7
#            ...
# 3853    Categoria13
# 3854    Categoria13
# 3855    Categoria13
# 3856    Categoria13
# 3857    Categoria13
# Name: review_scores_communication, Length: 3858, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_6 = freq_tbl(Portland['review_scores_communication'])
variable_6
# Out:
#    review_scores_communication  frequency  percentage  cumulative_perc
# 0                  Categoria13       1824    0.472784         0.571608
# 1                   Categoría8        210    0.054432         0.637418
# 2                  Categoría11        174    0.045101         0.691946
# 3                  Categoría10        167    0.043287         0.744281
# 4                  Categoría12        148    0.038362         0.790661
# 5                   Categoría9        136    0.035251         0.833281
# 6                   Categoría4        105    0.027216         0.866186
# 7                   Categoría6        103    0.026698         0.898464
# 8                   Categoría7         99    0.025661         0.929489
# 9                   Categoría3         82    0.021255         0.955186
# 10                  Categoría5         76    0.019699         0.979003
# 11                  Categoría2         52    0.013478         0.995299
# 12                  Categoría1         15    0.003888         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_6_2 = variable_6.drop(['percentage', 'cumulative_perc'], axis=1)
variable_6_2
# Out:
#    review_scores_communication  frequency
# 0                  Categoria13       1824
# 1                   Categoría8        210
# 2                  Categoría11        174
# 3                  Categoría10        167
# 4                  Categoría12        148
# 5                   Categoría9        136
# 6                   Categoría4        105
# 7                   Categoría6        103
# 8                   Categoría7         99
# 9                   Categoría3         82
# 10                  Categoría5         76
# 11                  Categoría2         52
# 12                  Categoría1         15

# %%
filtro_6 = variable_6_2[variable_6_2['frequency'] > 100]
filtro_6
# Out:
#   review_scores_communication  frequency
# 0                 Categoria13       1824
# 1                  Categoría8        210
# 2                 Categoría11        174
# 3                 Categoría10        167
# 4                 Categoría12        148
# 5                  Categoría9        136
# 6                  Categoría4        105
# 7                  Categoría6        103

# %%
#Ajusto el indice de mi DataFrame
filtro_i6 = filtro_6.set_index('review_scores_communication')
filtro_i6
# Out:
#                              frequency
# review_scores_communication
# Categoria13                       1824
# Categoría8                         210
# Categoría11                        174
# Categoría10                        167
# Categoría12                        148
# Categoría9                         136
# Categoría4                         105
# Categoría6                         103

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i6.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_communication'>

# %%
Portland['review_scores_checkin'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland['review_scores_checkin'].min()  
Max = Portland['review_scores_checkin'].max()  
Limites = [Min,Max]
Limites
# Out:
# [3.88, 5.0]

# %%
R = Max - Min
R
# Out:
# 1.12

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.08021751164933216

# %%
# Ver resultado
intervalos = np.linspace(4.5, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.5       , 4.53846154, 4.57692308, 4.61538462, 4.65384615,
#        4.69230769, 4.73076923, 4.76923077, 4.80769231, 4.84615385,
#        4.88461538, 4.92307692, 4.96153846, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
Portland['review_scores_checkin'] = pd.cut(x = Portland['review_scores_checkin'], bins = intervalos, labels = categorias)
Portland['review_scores_checkin']
# Out:
# 0       Categoría11
# 1       Categoria13
# 2        Categoría8
# 3       Categoria13
# 4       Categoría11
#            ...
# 3853    Categoria13
# 3854    Categoria13
# 3855            NaN
# 3856    Categoria13
# 3857    Categoria13
# Name: review_scores_checkin, Length: 3858, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_7 = freq_tbl(Portland['review_scores_checkin'])
variable_7
# Out:
#    review_scores_checkin  frequency  percentage  cumulative_perc
# 0            Categoria13       1757    0.455417         0.490371
# 1            Categoría11        388    0.100570         0.598660
# 2            Categoría12        361    0.093572         0.699414
# 3            Categoría10        267    0.069207         0.773932
# 4             Categoría9        176    0.045619         0.823053
# 5             Categoría8        175    0.045360         0.871895
# 6             Categoría5        128    0.033178         0.907619
# 7             Categoría7        115    0.029808         0.939715
# 8             Categoría6         89    0.023069         0.964555
# 9             Categoría4         44    0.011405         0.976835
# 10            Categoría2         38    0.009850         0.987441
# 11            Categoría3         38    0.009850         0.998046
# 12            Categoría1          7    0.001814         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_7_2 = variable_7.drop(['percentage', 'cumulative_perc'], axis=1)
variable_7_2
# Out:
#    review_scores_checkin  frequency
# 0            Categoria13       1757
# 1            Categoría11        388
# 2            Categoría12        361
# 3            Categoría10        267
# 4             Categoría9        176
# 5             Categoría8        175
# 6             Categoría5        128
# 7             Categoría7        115
# 8             Categoría6         89
# 9             Categoría4         44
# 10            Categoría2         38
# 11            Categoría3         38
# 12            Categoría1          7

# %%
filtro_7 = variable_7_2[variable_7_2['frequency'] > 100]
filtro_7
# Out:
#   review_scores_checkin  frequency
# 0           Categoria13       1757
# 1           Categoría11        388
# 2           Categoría12        361
# 3           Categoría10        267
# 4            Categoría9        176
# 5            Categoría8        175
# 6            Categoría5        128
# 7            Categoría7        115

# %%
#Ajusto el indice de mi DataFrame
filtro_i7 = filtro_7.set_index('review_scores_checkin')
filtro_i7
# Out:
#                        frequency
# review_scores_checkin
# Categoria13                 1757
# Categoría11                  388
# Categoría12                  361
# Categoría10                  267
# Categoría9                   176
# Categoría8                   175
# Categoría5                   128
# Categoría7                   115

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i7.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Evaluación de reseñas')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland['review_scores_cleanliness'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland['review_scores_cleanliness'].min()  
Max = Portland['review_scores_cleanliness'].max()  
Limites = [Min,Max]
Limites
# Out:
# [3.5, 5.0]

# %%
R = Max - Min
R
# Out:
# 1.5

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.10743416738749842

# %%
# Ver resultado
intervalos = np.linspace(4.13, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.13      , 4.19692308, 4.26384615, 4.33076923, 4.39769231,
#        4.46461538, 4.53153846, 4.59846154, 4.66538462, 4.73230769,
#        4.79923077, 4.86615385, 4.93307692, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
Portland['review_scores_cleanliness'] = pd.cut(x = Portland['review_scores_cleanliness'], bins = intervalos, labels = categorias)
Portland['review_scores_cleanliness']
# Out:
# 0       Categoría11
# 1       Categoria13
# 2        Categoría3
# 3       Categoria13
# 4       Categoría12
#            ...
# 3853    Categoria13
# 3854    Categoria13
# 3855    Categoria13
# 3856    Categoria13
# 3857    Categoria13
# Name: review_scores_cleanliness, Length: 3858, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_8 = freq_tbl(Portland['review_scores_cleanliness'])
variable_8
# Out:
#    review_scores_cleanliness  frequency  percentage  cumulative_perc
# 0                Categoria13       1491    0.386470         0.410066
# 1                Categoría11        447    0.115863         0.533003
# 2                Categoría12        431    0.111716         0.651540
# 3                 Categoría9        289    0.074909         0.731023
# 4                Categoría10        273    0.070762         0.806106
# 5                 Categoría6        163    0.042250         0.850935
# 6                 Categoría8        146    0.037843         0.891089
# 7                 Categoría5         95    0.024624         0.917217
# 8                 Categoría7         93    0.024106         0.942794
# 9                 Categoría3         84    0.021773         0.965897
# 10                Categoría2         65    0.016848         0.983773
# 11                Categoría4         36    0.009331         0.993674
# 12                Categoría1         23    0.005962         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_8_2 = variable_8.drop(['percentage', 'cumulative_perc'], axis=1)
variable_8_2
# Out:
#    review_scores_cleanliness  frequency
# 0                Categoria13       1491
# 1                Categoría11        447
# 2                Categoría12        431
# 3                 Categoría9        289
# 4                Categoría10        273
# 5                 Categoría6        163
# 6                 Categoría8        146
# 7                 Categoría5         95
# 8                 Categoría7         93
# 9                 Categoría3         84
# 10                Categoría2         65
# 11                Categoría4         36
# 12                Categoría1         23

# %%
filtro_8 = variable_8_2[variable_8_2['frequency'] > 100]
filtro_8
# Out:
#   review_scores_cleanliness  frequency
# 0               Categoria13       1491
# 1               Categoría11        447
# 2               Categoría12        431
# 3                Categoría9        289
# 4               Categoría10        273
# 5                Categoría6        163
# 6                Categoría8        146

# %%
#Ajusto el indice de mi DataFrame
filtro_i8 = filtro_8.set_index('review_scores_cleanliness')
filtro_i8
# Out:
#                            frequency
# review_scores_cleanliness
# Categoria13                     1491
# Categoría11                      447
# Categoría12                      431
# Categoría9                       289
# Categoría10                      273
# Categoría6                       163
# Categoría8                       146

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i8.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Puntuación de limpieza')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland['review_scores_accuracy'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland['review_scores_accuracy'].min()  
Max = Portland['review_scores_accuracy'].max()  
Limites = [Min,Max]
Limites
# Out:
# [3.75, 5.0]

# %%
R = Max - Min
R
# Out:
# 1.25

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.08952847282291534

# %%
# Ver resultado
intervalos = np.linspace(4.4, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.4       , 4.44615385, 4.49230769, 4.53846154, 4.58461538,
#        4.63076923, 4.67692308, 4.72307692, 4.76923077, 4.81538462,
#        4.86153846, 4.90769231, 4.95384615, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
Portland['review_scores_accuracy'] = pd.cut(x = Portland['review_scores_accuracy'], bins = intervalos, labels = categorias)
Portland['review_scores_accuracy']
# Out:
# 0       Categoría11
# 1        Categoría9
# 2        Categoría8
# 3       Categoria13
# 4       Categoría11
#            ...
# 3853    Categoria13
# 3854    Categoria13
# 3855    Categoria13
# 3856    Categoria13
# 3857    Categoria13
# Name: review_scores_accuracy, Length: 3858, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_9 = freq_tbl(Portland['review_scores_accuracy'])
variable_9
# Out:
#    review_scores_accuracy  frequency  percentage  cumulative_perc
# 0             Categoria13       1550    0.401763         0.428177
# 1             Categoría12        393    0.101866         0.536740
# 2              Categoría9        327    0.084759         0.627072
# 3             Categoría10        308    0.079834         0.712155
# 4             Categoría11        283    0.073354         0.790331
# 5              Categoría8        170    0.044064         0.837293
# 6              Categoría6        142    0.036807         0.876519
# 7              Categoría3        129    0.033437         0.912155
# 8              Categoría7        116    0.030067         0.944199
# 9              Categoría5         77    0.019959         0.965470
# 10             Categoría4         76    0.019699         0.986464
# 11             Categoría1         27    0.006998         0.993923
# 12             Categoría2         22    0.005702         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_9_2 = variable_9.drop(['percentage', 'cumulative_perc'], axis=1)
variable_9_2
# Out:
#    review_scores_accuracy  frequency
# 0             Categoria13       1550
# 1             Categoría12        393
# 2              Categoría9        327
# 3             Categoría10        308
# 4             Categoría11        283
# 5              Categoría8        170
# 6              Categoría6        142
# 7              Categoría3        129
# 8              Categoría7        116
# 9              Categoría5         77
# 10             Categoría4         76
# 11             Categoría1         27
# 12             Categoría2         22

# %%
filtro_9 = variable_9_2[variable_9_2['frequency'] > 100]
filtro_9
# Out:
#   review_scores_accuracy  frequency
# 0            Categoria13       1550
# 1            Categoría12        393
# 2             Categoría9        327
# 3            Categoría10        308
# 4            Categoría11        283
# 5             Categoría8        170
# 6             Categoría6        142
# 7             Categoría3        129
# 8             Categoría7        116

# %%
#Ajusto el indice de mi DataFrame
filtro_i9 = filtro_9.set_index('review_scores_accuracy')
filtro_i9
# Out:
#                         frequency
# review_scores_accuracy
# Categoria13                  1550
# Categoría12                   393
# Categoría9                    327
# Categoría10                   308
# Categoría11                   283
# Categoría8                    170
# Categoría6                    142
# Categoría3                    129
# Categoría7                    116

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i9.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Evaluación de precisión')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Eliminar % y convertir a número
Portland["host_response_rate"] = Portland["host_response_rate"].str.replace('%', '', regex=True).astype(float) / 100

# %%
Portland['host_response_rate'].info()
n=8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland["host_response_rate"].min()  
Max = Portland["host_response_rate"].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 1.0]

# %%
R = Max - Min
R
# Out:
# 1.0

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.07162277825833228

# %%
# Ver resultado
intervalos = np.linspace(0.0, 1.0, 13) #Número de clases más uno
intervalos
# Out:
# array([0.        , 0.08333333, 0.16666667, 0.25      , 0.33333333,
#        0.41666667, 0.5       , 0.58333333, 0.66666667, 0.75      ,
#        0.83333333, 0.91666667, 1.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",]

# %%
Portland["host_response_rate"] = pd.cut(x = Portland["host_response_rate"], bins = intervalos, labels = categorias)
Portland["host_response_rate"]
# Out:
# 0               NaN
# 1       Categoría12
# 2       Categoría12
# 3       Categoría12
# 4       Categoría12
#            ...
# 3853    Categoría12
# 3854    Categoría12
# 3855    Categoría12
# 3856    Categoría12
# 3857    Categoría12
# Name: host_response_rate, Length: 3858, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_10 = freq_tbl(Portland["host_response_rate"])
variable_10
# Out:
#    host_response_rate  frequency  percentage  cumulative_perc
# 0         Categoría12       2890    0.749093         0.774384
# 1         Categoría11        269    0.069725         0.846463
# 2          Categoría9        153    0.039658         0.887460
# 3         Categoría10        152    0.039399         0.928189
# 4          Categoría6         73    0.018922         0.947749
# 5          Categoría8         66    0.017107         0.965434
# 6          Categoría3         39    0.010109         0.975884
# 7          Categoría4         33    0.008554         0.984727
# 8          Categoría5         28    0.007258         0.992229
# 9          Categoría2         22    0.005702         0.998124
# 10         Categoría7          7    0.001814         1.000000
# 11         Categoría1          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_10_2 = variable_10.drop(['percentage', 'cumulative_perc'], axis=1)
variable_10_2
# Out:
#    host_response_rate  frequency
# 0         Categoría12       2890
# 1         Categoría11        269
# 2          Categoría9        153
# 3         Categoría10        152
# 4          Categoría6         73
# 5          Categoría8         66
# 6          Categoría3         39
# 7          Categoría4         33
# 8          Categoría5         28
# 9          Categoría2         22
# 10         Categoría7          7
# 11         Categoría1          0

# %%
filtro_10 = variable_10_2[variable_10_2['frequency'] > 100]
filtro_10
# Out:
#   host_response_rate  frequency
# 0        Categoría12       2890
# 1        Categoría11        269
# 2         Categoría9        153
# 3        Categoría10        152

# %%
#Ajusto el indice de mi DataFrame
filtro_i10 = filtro_10.set_index("host_response_rate")
filtro_i10
# Out:
#                     frequency
# host_response_rate
# Categoría12              2890
# Categoría11               269
# Categoría9                153
# Categoría10               152

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i10.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Tiempo de respuesta del host')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Eliminar % y convertir a número
Portland["host_acceptance_rate"] = Portland["host_acceptance_rate"].str.replace('%', '', regex=True).astype(float) / 100 
Portland['host_acceptance_rate'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland["host_acceptance_rate"].min()  
Max = Portland["host_acceptance_rate"].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 1.0]

# %%
R = Max - Min
R
# Out:
# 1.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 0.07162277825833228

# %%
# Ver resultado
intervalos = np.linspace(0.0, 1.0, 13) #Número de clases más uno
intervalos
# Out:
# array([0.        , 0.08333333, 0.16666667, 0.25      , 0.33333333,
#        0.41666667, 0.5       , 0.58333333, 0.66666667, 0.75      ,
#        0.83333333, 0.91666667, 1.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
Portland["host_acceptance_rate"] = pd.cut(x = Portland["host_acceptance_rate"], bins = intervalos, labels = categorias)
Portland["host_acceptance_rate"]
# Out:
# 0        Categoría1
# 1       Categoría12
# 2       Categoría10
# 3       Categoría12
# 4        Categoría9
#            ...
# 3853    Categoría12
# 3854     Categoría6
# 3855    Categoría12
# 3856     Categoría9
# 3857     Categoría8
# Name: host_acceptance_rate, Length: 3858, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_11 = freq_tbl(Portland["host_acceptance_rate"])
variable_11
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0           Categoría12       1545    0.400467         0.416218
# 1           Categoría11        440    0.114049         0.534752
# 2            Categoría9        300    0.077760         0.615571
# 3           Categoría10        296    0.076724         0.695312
# 4            Categoría6        233    0.060394         0.758082
# 5            Categoría3        177    0.045879         0.805765
# 6            Categoría7        163    0.042250         0.849677
# 7            Categoría4        161    0.041731         0.893050
# 8            Categoría8        161    0.041731         0.936422
# 9            Categoría5        127    0.032919         0.970636
# 10           Categoría2         70    0.018144         0.989494
# 11           Categoría1         39    0.010109         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_11_2 = variable_11.drop(['percentage', 'cumulative_perc'], axis=1)
variable_11_2
# Out:
#    host_acceptance_rate  frequency
# 0           Categoría12       1545
# 1           Categoría11        440
# 2            Categoría9        300
# 3           Categoría10        296
# 4            Categoría6        233
# 5            Categoría3        177
# 6            Categoría7        163
# 7            Categoría4        161
# 8            Categoría8        161
# 9            Categoría5        127
# 10           Categoría2         70
# 11           Categoría1         39

# %%
filtro_11 = variable_11_2[variable_11_2['frequency'] > 300]
filtro_11
# Out:
#   host_acceptance_rate  frequency
# 0          Categoría12       1545
# 1          Categoría11        440

# %%
#Ajusto el indice de mi DataFrame
filtro_i11 = filtro_11.set_index("host_acceptance_rate")
filtro_i11
# Out:
#                       frequency
# host_acceptance_rate
# Categoría12                1545
# Categoría11                 440

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i11.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='host_acceptance_rate'>

# %%
Portland['host_total_listings_count'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland["host_total_listings_count"].min()  
Max = Portland["host_total_listings_count"].max()  
Limites = [Min,Max]
Limites
# Out:
# [1.0, 131.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 130.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 9.310961173583197

# %%
# Ver resultado
intervalos = np.linspace(1.0, 6.0, 13) #Número de clases más uno
intervalos
# Out:
# array([1.        , 1.41666667, 1.83333333, 2.25      , 2.66666667,
#        3.08333333, 3.5       , 3.91666667, 4.33333333, 4.75      ,
#        5.16666667, 5.58333333, 6.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
Portland["host_total_listings_count"] = pd.cut(x = Portland["host_total_listings_count"], bins = intervalos, labels = categorias)
Portland["host_total_listings_count"]
# Out:
# 0       Categoría5
# 1       Categoría5
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 3853           NaN
# 3854           NaN
# 3855    Categoría3
# 3856           NaN
# 3857           NaN
# Name: host_total_listings_count, Length: 3858, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_12 = freq_tbl(Portland["host_total_listings_count"])
variable_12
# Out:
#    host_total_listings_count  frequency  percentage  cumulative_perc
# 0                 Categoría3        766    0.198548         0.482064
# 1                 Categoría5        356    0.092276         0.706104
# 2                Categoría10        194    0.050285         0.828194
# 3                 Categoría8        174    0.045101         0.937697
# 4                Categoría12         99    0.025661         1.000000
# 5                 Categoría1          0    0.000000         1.000000
# 6                 Categoría2          0    0.000000         1.000000
# 7                 Categoría4          0    0.000000         1.000000
# 8                 Categoría6          0    0.000000         1.000000
# 9                 Categoría7          0    0.000000         1.000000
# 10                Categoría9          0    0.000000         1.000000
# 11               Categoría11          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_12_2 = variable_12.drop(['percentage', 'cumulative_perc'], axis=1)
variable_12_2
# Out:
#    host_total_listings_count  frequency
# 0                 Categoría3        766
# 1                 Categoría5        356
# 2                Categoría10        194
# 3                 Categoría8        174
# 4                Categoría12         99
# 5                 Categoría1          0
# 6                 Categoría2          0
# 7                 Categoría4          0
# 8                 Categoría6          0
# 9                 Categoría7          0
# 10                Categoría9          0
# 11               Categoría11          0

# %%
filtro_12 = variable_12_2[variable_12_2['frequency'] > 165]
filtro_12
# Out:
#   host_total_listings_count  frequency
# 0                Categoría3        766
# 1                Categoría5        356
# 2               Categoría10        194
# 3                Categoría8        174

# %%
#Ajusto el indice de mi DataFrame
filtro_i12 = filtro_12.set_index("host_total_listings_count")
filtro_i12
# Out:
#                            frequency
# host_total_listings_count
# Categoría3                       766
# Categoría5                       356
# Categoría10                      194
# Categoría8                       174

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro_i12["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
Portland['accommodates'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland["accommodates"].min()  
Max = Portland["accommodates"].max()  
Limites = [Min,Max]
Limites
# Out:
# [1.0, 8.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 7.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 0.501359447808326

# %%
# Ver resultado
intervalos = np.linspace(1.0, 7.0, 13) #Número de clases más uno
intervalos
# Out:
# array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
Portland["accommodates"] = pd.cut(x = Portland["accommodates"], bins = intervalos, labels = categorias)
Portland["accommodates"]
# Out:
# 0        Categoría2
# 1       Categoría10
# 2        Categoría2
# 3        Categoría6
# 4        Categoría2
#            ...
# 3853    Categoría10
# 3854     Categoría2
# 3855            NaN
# 3856     Categoría2
# 3857     Categoría2
# Name: accommodates, Length: 3858, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_13 = freq_tbl(Portland["accommodates"])
variable_13
# Out:
#    accommodates  frequency  percentage  cumulative_perc
# 0    Categoría2       1856    0.481078         0.554361
# 1    Categoría6        652    0.168999         0.749104
# 2    Categoría4        497    0.128823         0.897551
# 3    Categoría8        151    0.039139         0.942652
# 4   Categoría10        150    0.038880         0.987455
# 5   Categoría12         42    0.010886         1.000000
# 6    Categoría1          0    0.000000         1.000000
# 7    Categoría3          0    0.000000         1.000000
# 8    Categoría5          0    0.000000         1.000000
# 9    Categoría7          0    0.000000         1.000000
# 10   Categoría9          0    0.000000         1.000000
# 11  Categoría11          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_13_2 = variable_13.drop(['percentage', 'cumulative_perc'], axis=1)
variable_13_2
# Out:
#    accommodates  frequency
# 0    Categoría2       1856
# 1    Categoría6        652
# 2    Categoría4        497
# 3    Categoría8        151
# 4   Categoría10        150
# 5   Categoría12         42
# 6    Categoría1          0
# 7    Categoría3          0
# 8    Categoría5          0
# 9    Categoría7          0
# 10   Categoría9          0
# 11  Categoría11          0

# %%
filtro_13 = variable_13_2[variable_13_2['frequency'] > 100]
filtro_13
# Out:
#   accommodates  frequency
# 0   Categoría2       1856
# 1   Categoría6        652
# 2   Categoría4        497
# 3   Categoría8        151
# 4  Categoría10        150

# %%
#Ajusto el indice de mi DataFrame
filtro_i13 = filtro_13.set_index("accommodates")
filtro_i13
# Out:
#               frequency
# accommodates
# Categoría2         1856
# Categoría6          652
# Categoría4          497
# Categoría8          151
# Categoría10         150

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i13.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='accommodates'>

# %%
# Extraer número de baños de bathrooms_text
Portland["bathrooms"] = Portland["bathrooms"].str.extract("(\d+\.?\d*)").astype(float)
Portland['bathrooms'].info()
n = 8021
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[281], line 2
#       1 # Extraer número de baños de bathrooms_text
# ----> 2 Portland["bathrooms"] = Portland["bathrooms"].str.extract("(\d+\.?\d*)").astype(float)
#       3 Portland['bathrooms'].info()
#       4 n = 8021
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
Min = Portland["bathrooms_text"].min()  
Max = Portland["bathrooms_text"].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 8.0]

# %%
R = Max - Min
R
# Out:
# 8.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 0.5729822260666583

# %%
# Ver resultado
intervalos = np.linspace(0.0, 27.0, 13) #Número de clases más uno
intervalos
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
Portland["bathrooms_text"] = pd.cut(x = Portland["bathrooms_text"], bins = intervalos, labels = categorias)
Portland["bathrooms_text"]
# Out:
# 0       Categoría1
# 1       Categoría1
# 2       Categoría1
# 3       Categoría1
# 4       Categoría1
#            ...
# 3853    Categoría1
# 3854    Categoría1
# 3855    Categoría1
# 3856    Categoría1
# 3857    Categoría1
# Name: bathrooms_text, Length: 3858, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_14 = freq_tbl(Portland["bathrooms_text"])
variable_14
# Out:
#    bathrooms_text  frequency  percentage  cumulative_perc
# 0      Categoría1       3718    0.963712         0.979452
# 1      Categoría2         76    0.019699         0.999473
# 2      Categoría3          1    0.000259         0.999737
# 3      Categoría4          1    0.000259         1.000000
# 4      Categoría5          0    0.000000         1.000000
# 5      Categoría6          0    0.000000         1.000000
# 6      Categoría7          0    0.000000         1.000000
# 7      Categoría8          0    0.000000         1.000000
# 8      Categoría9          0    0.000000         1.000000
# 9     Categoría10          0    0.000000         1.000000
# 10    Categoría11          0    0.000000         1.000000
# 11    Categoría12          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_14_2 = variable_14.drop(['percentage', 'cumulative_perc'], axis=1)
variable_14_2
# Out:
#    bathrooms_text  frequency
# 0      Categoría1       3718
# 1      Categoría2         76
# 2      Categoría3          1
# 3      Categoría4          1
# 4      Categoría5          0
# 5      Categoría6          0
# 6      Categoría7          0
# 7      Categoría8          0
# 8      Categoría9          0
# 9     Categoría10          0
# 10    Categoría11          0
# 11    Categoría12          0

# %%
filtro_14 = variable_14_2[variable_14_2['frequency'] > 100]
filtro_14
# Out:
#   bathrooms_text  frequency
# 0     Categoría1       3718

# %%
#Ajusto el indice de mi DataFrame
filtro_i14 = filtro_14.set_index("bathrooms_text")
filtro_i14
# Out:
#                 frequency
# bathrooms_text
# Categoría1           3718

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i14.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='bathrooms_text'>

# %%
Portland['beds'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland["beds"].min()  
Max = Portland["beds"].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 5.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 5.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 0.3581138912916614

# %%
# Ver resultado
intervalos = np.linspace(0.0, 3.0, 13) #Número de clases más uno
intervalos
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
Portland["beds"] = pd.cut(x = Portland["beds"], bins = intervalos, labels = categorias)
Portland["beds"]
# Out:
# 0       Categoría4
# 1       Categoría4
# 2       Categoría4
# 3       Categoría8
# 4       Categoría4
#            ...
# 3853           NaN
# 3854    Categoría8
# 3855    Categoría4
# 3856    Categoría4
# 3857    Categoría4
# Name: beds, Length: 3858, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_15 = freq_tbl(Portland["beds"])
variable_15
# Out:
#            beds  frequency  percentage  cumulative_perc
# 0    Categoría4       2210    0.572836         0.624470
# 1    Categoría8        975    0.252722         0.899972
# 2   Categoría12        274    0.071021         0.977395
# 3    Categoría6         80    0.020736         1.000000
# 4    Categoría1          0    0.000000         1.000000
# 5    Categoría2          0    0.000000         1.000000
# 6    Categoría3          0    0.000000         1.000000
# 7    Categoría5          0    0.000000         1.000000
# 8    Categoría7          0    0.000000         1.000000
# 9    Categoría9          0    0.000000         1.000000
# 10  Categoría10          0    0.000000         1.000000
# 11  Categoría11          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_15_2 = variable_15.drop(['percentage', 'cumulative_perc'], axis=1)
variable_15_2
# Out:
#            beds  frequency
# 0    Categoría4       2210
# 1    Categoría8        975
# 2   Categoría12        274
# 3    Categoría6         80
# 4    Categoría1          0
# 5    Categoría2          0
# 6    Categoría3          0
# 7    Categoría5          0
# 8    Categoría7          0
# 9    Categoría9          0
# 10  Categoría10          0
# 11  Categoría11          0

# %%
filtro15 = variable_15_2[variable_15_2['frequency'] > 300]
filtro15
# Out:
#          beds  frequency
# 0  Categoría4       2210
# 1  Categoría8        975

# %%
#Ajusto el indice de mi DataFrame
filtro_i15 = filtro15.set_index("beds")
filtro_i15
# Out:
#             frequency
# beds
# Categoría4       2210
# Categoría8        975

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i15.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Camas')
plt.xlabel('Categoria de las camas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
Portland["price"] = Portland["price"].replace('[\$,]', '', regex=True).astype(float)
Portland['price'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland["price"].min()  
Max = Portland["price"].max()  
Limites = [Min,Max]
Limites
# Out:
# [23.0, 2222.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 2199.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 157.49848939007268

# %%
# Ver resultado
intervalos = np.linspace(20.0, 96274.0, 13) #Número de clases más uno
intervalos
# Out:
# array([2.00000000e+01, 8.04116667e+03, 1.60623333e+04, 2.40835000e+04,
#        3.21046667e+04, 4.01258333e+04, 4.81470000e+04, 5.61681667e+04,
#        6.41893333e+04, 7.22105000e+04, 8.02316667e+04, 8.82528333e+04,
#        9.62740000e+04])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
Portland["price"] = pd.cut(x = Portland["price"], bins = intervalos, labels = categorias)
Portland["price"]
# Out:
# 0       Categoría1
# 1       Categoría1
# 2       Categoría1
# 3       Categoría1
# 4       Categoría1
#            ...
# 3853    Categoría1
# 3854    Categoría1
# 3855    Categoría1
# 3856    Categoría1
# 3857    Categoría1
# Name: price, Length: 3858, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_16 = freq_tbl(Portland["price"])
variable_16
# Out:
#           price  frequency  percentage  cumulative_perc
# 0    Categoría1       3858         1.0              1.0
# 1    Categoría2          0         0.0              1.0
# 2    Categoría3          0         0.0              1.0
# 3    Categoría4          0         0.0              1.0
# 4    Categoría5          0         0.0              1.0
# 5    Categoría6          0         0.0              1.0
# 6    Categoría7          0         0.0              1.0
# 7    Categoría8          0         0.0              1.0
# 8    Categoría9          0         0.0              1.0
# 9   Categoría10          0         0.0              1.0
# 10  Categoría11          0         0.0              1.0
# 11  Categoría12          0         0.0              1.0

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_16_2 = variable_16.drop(['percentage', 'cumulative_perc'], axis=1)
variable_16_2
# Out:
#           price  frequency
# 0    Categoría1       3858
# 1    Categoría2          0
# 2    Categoría3          0
# 3    Categoría4          0
# 4    Categoría5          0
# 5    Categoría6          0
# 6    Categoría7          0
# 7    Categoría8          0
# 8    Categoría9          0
# 9   Categoría10          0
# 10  Categoría11          0
# 11  Categoría12          0

# %%
filtro16 = variable_16_2[variable_16_2['frequency'] > 0]
filtro16
# Out:
#         price  frequency
# 0  Categoría1       3858

# %%
#Ajusto el indice de mi DataFrame
filtro_i16 = filtro16.set_index("price")
filtro_i16
# Out:
#             frequency
# price
# Categoría1       3858

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i16.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='price'>

# %%
Portland['maximum_nights_avg_ntm'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3858 entries, 0 to 3857
# Series name: maximum_nights_avg_ntm
# Non-Null Count  Dtype
# --------------  -----
# 3858 non-null   float64
# dtypes: float64(1)
# memory usage: 30.3 KB

# %%
Min = Portland["maximum_nights_avg_ntm"].min()  
Max = Portland["maximum_nights_avg_ntm"].max()  
Limites = [Min,Max]
Limites
# Out:
# [1.0, 1125.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 1124.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 80.50400276236549

# %%
# Ver resultado
intervalos = np.linspace(1.0, 20770.8, 13) #Número de clases más uno
intervalos
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
Portland["maximum_nights_avg_ntm"] = pd.cut(x = Portland["maximum_nights_avg_ntm"], bins = intervalos, labels = categorias)
Portland["maximum_nights_avg_ntm"]
# Out:
# 0       Categoría1
# 1       Categoría1
# 2       Categoría1
# 3       Categoría1
# 4       Categoría1
#            ...
# 3853    Categoría1
# 3854    Categoría1
# 3855    Categoría1
# 3856    Categoría1
# 3857    Categoría1
# Name: maximum_nights_avg_ntm, Length: 3858, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_17 = freq_tbl(Portland["maximum_nights_avg_ntm"])
variable_17
# Out:
#    maximum_nights_avg_ntm  frequency  percentage  cumulative_perc
# 0              Categoría1       3851    0.998186              1.0
# 1              Categoría2          0    0.000000              1.0
# 2              Categoría3          0    0.000000              1.0
# 3              Categoría4          0    0.000000              1.0
# 4              Categoría5          0    0.000000              1.0
# 5              Categoría6          0    0.000000              1.0
# 6              Categoría7          0    0.000000              1.0
# 7              Categoría8          0    0.000000              1.0
# 8              Categoría9          0    0.000000              1.0
# 9             Categoría10          0    0.000000              1.0
# 10            Categoría11          0    0.000000              1.0
# 11            Categoría12          0    0.000000              1.0

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_17_2 = variable_17.drop(['percentage', 'cumulative_perc'], axis=1)
variable_17_2
# Out:
#    maximum_nights_avg_ntm  frequency
# 0              Categoría1       3851
# 1              Categoría2          0
# 2              Categoría3          0
# 3              Categoría4          0
# 4              Categoría5          0
# 5              Categoría6          0
# 6              Categoría7          0
# 7              Categoría8          0
# 8              Categoría9          0
# 9             Categoría10          0
# 10            Categoría11          0
# 11            Categoría12          0

# %%
filtro_17 = variable_17_2[variable_17_2['frequency'] > 0]
filtro_17
# Out:
#   maximum_nights_avg_ntm  frequency
# 0             Categoría1       3851

# %%
#Ajusto el indice de mi DataFrame
filtro_i17 = filtro_17.set_index("maximum_nights_avg_ntm")
filtro_i17
# Out:
#                         frequency
# maximum_nights_avg_ntm
# Categoría1                   3851

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i17.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('maximum_nights_avg_ntm')
plt.xlabel('Maxima noche')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
